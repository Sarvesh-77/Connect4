# %%
from re import VERBOSE
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from collections import deque
import random
from tqdm import tqdm
import copy

# %%
class Connect4:
    def __init__(self, rew, inv):
        self.rows = 6
        self.cols = 7
        self.board = np.zeros((self.rows, self.cols))
        self.player = 1
        self.winning_length = 4
        self.inv = inv
        self.rew = rew

    def reset(self):
        self.board = np.zeros((self.rows, self.cols))
        self.player = 1
        return self.board.copy()

    def is_valid_move(self, col):
        return self.board[0][col] == 0

    def make_move(self, col):
        for row in range(self.rows - 1, -1, -1):
            if self.board[row][col] == 0:
                self.board[row][col] = self.player
                return row, col

    def check_winner(self, row, col):
        directions = [(0, 1), (1, 0), (1, 1), (1, -1)]
        for dr, dc in directions:
            count = 1
            r, c = row + dr, col + dc
            while 0 <= r < self.rows and 0 <= c < self.cols and self.board[r][c] == self.player:
                count += 1
                r += dr
                c += dc
            r, c = row - dr, col - dc
            while 0 <= r < self.rows and 0 <= c < self.cols and self.board[r][c] == self.player:
                count += 1
                r -= dr
                c -= dc
            if count >= self.winning_length:
                return True
        return False

    def is_board_full(self):
        return np.all(self.board != 0)

    def step(self, action):
        if self.player == 1:
          win = 1
        else:
          win = -1
        if not self.is_valid_move(action):
            return self.board.copy(), -self.inv*win, True
        row, col = self.make_move(action)
        if self.check_winner(row, col):
            return self.board.copy(), self.rew*win, True
        if self.is_board_full():
            return self.board.copy(), 0, True
        self.player = 3 - self.player  # Switch player
        return self.board.copy(), 0, False

    def render(self):
        print(self.board)

    @property
    def observation_space(self):
        return self.board.shape

    @property
    def action_space(self):
        return self.cols

# %%
FCNN = models.Sequential([
    layers.Input(shape=(6,7)),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(7)  # Output layer for Q-values
])
FCNN.compile(loss='mean_squared_error', optimizer=optimizers.Adam())

CNN = models.Sequential([
    layers.Reshape((6, 7, 1), input_shape=(6, 7)),
    layers.Conv2D(256, (3,3), activation='relu', padding = 'valid'),
    layers.Conv2D(128, (3,3), activation='relu', padding = 'valid'),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(7)  # Output layer for Q-values
])
CNN.compile(loss='mean_squared_error', optimizer=optimizers.Adam())

# %%
import copy

class DQNAgent:
    def __init__(self, model):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=1000)  # Replay memory
        self.gamma = 0.95  # Discount factor
        self.epsilon = 0.2  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        self.batch_size = 32
        self.online_network = copy.deepcopy(model)
        self.target_network = copy.deepcopy(model)
        self.update_target_network()

    def valid(self, state):
        return np.array([min(np.abs(state[0][col]), 1) for col in range(7)])

    def change(self, state):
        state[state == 2] = -1
        return state

    def update_target_network(self):
        self.target_network.set_weights(self.online_network.get_weights())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((self.change(state).reshape(1,6,7), action, reward, self.change(next_state).reshape(1,6,7), done))

    def act(self, state):
        valid = self.valid(state)
        state = self.change(state)
        if np.random.rand() <= self.epsilon:
            return np.random.choice(np.where(valid == 0)[0])
            #return np.random.choice(self.action_size)
        state = state.reshape(1,6,7)
        q_values = self.online_network.predict(state, verbose=0)
        return np.argmax(q_values[0] - valid*10000)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in minibatch:
            valid = self.valid(state)
            target = self.online_network.predict(state, verbose=0)
            if done:
                target[0][action] = reward
            else:
                target[0][action] = reward + self.gamma * np.amax(self.target_network.predict(next_state, verbose=0)[0])
                target[0] = target[0] - valid
            self.online_network.fit(state, target, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

def WDL_string(WDL):
  return str(WDL[rew]) + ' | ' + str(WDL[0]) + ' | ' + str(WDL[-rew]) + ' | ' + str(WDL[-inv]) + ' | ' + str(WDL[inv])

def transform(state):
  state[state == 0] = 3
  state = 3 - state
  return state

# Initialize the Connect4 environment and the agent
rew = 5
inv = 7
env = Connect4(rew, inv)
state_size = env.observation_space
action_size = env.action_space
agent = DQNAgent(CNN)
WDL = {rew:0, 0:0, -rew:0, -inv: 0, inv: 0}

# Train the agent
for episode in range(1000):
    state = env.reset()
    state = np.expand_dims(state, axis = 0)
    states = []
    actions = []
    for time_step in range(50):
        if time_step%2 == 0:
          action = agent.act(state)
        else:
          action = agent.act(transform(state))
        next_state, reward, done = env.step(action)
        if time_step%2:
          states.append(transform(state.copy()))
        else:
          states.append(state.copy())
        actions.append(action)
        state = next_state
        if done:
            WDL[reward] += 1
            print('Episode:', str(episode+1) + '/1000', 'Reward:', reward, 'steps:', time_step, 'WDL:', '    ', WDL_string(WDL))
            break

    n = len(states)
    for i in range(n-2):
      agent.remember(states[i], actions[i], 0, states[i+2], 0)
    if np.abs(reward) == rew:
      for i in range(5):
        agent.remember(states[n-2], actions[n-2], -rew, states[n-1], 1)
        agent.remember(states[n-1], actions[n-1], rew, states[n-1], 1)
    elif reward == 0:
      agent.remember(states[n-2], actions[n-2], 0, states[n-1], 1)
      agent.remember(states[n-1], actions[n-1], 0, states[n-1], 1)
    else:
      agent.remember(states[n-1], actions[n-1], -inv, states[n-1], 1)
    if episode % 10 == 0:
        agent.update_target_network()

    agent.replay()

# Evaluate the agent
# Implement code to play Connect4 using the trained agent
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 17 variables whereas the saved optimizer has 1 variables.
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 17 variables whereas the saved optimizer has 1 variables.
# Episode: 1/1000 Reward: -100 steps: 7 WDL:      0 | 0 | 1 | 0 | 0
# Episode: 2/1000 Reward: 100 steps: 10 WDL:      1 | 0 | 1 | 0 | 0
# Episode: 3/1000 Reward: 100 steps: 10 WDL:      2 | 0 | 1 | 0 | 0
# Episode: 4/1000 Reward: -100 steps: 9 WDL:      2 | 0 | 2 | 0 | 0
# Episode: 5/1000 Reward: 1000 steps: 7 WDL:      2 | 0 | 2 | 0 | 1
# Episode: 6/1000 Reward: -100 steps: 7 WDL:      2 | 0 | 3 | 0 | 1
# Episode: 7/1000 Reward: 1000 steps: 7 WDL:      2 | 0 | 3 | 0 | 2
# Episode: 8/1000 Reward: 100 steps: 8 WDL:      3 | 0 | 3 | 0 | 2
# Episode: 9/1000 Reward: 1000 steps: 9 WDL:      3 | 0 | 3 | 0 | 3
# Episode: 10/1000 Reward: 100 steps: 6 WDL:      4 | 0 | 3 | 0 | 3
# Episode: 11/1000 Reward: 100 steps: 10 WDL:      5 | 0 | 3 | 0 | 3
# Episode: 12/1000 Reward: -1000 steps: 6 WDL:      5 | 0 | 3 | 1 | 3
# Episode: 13/1000 Reward: 1000 steps: 7 WDL:      5 | 0 | 3 | 1 | 4
# Episode: 14/1000 Reward: -100 steps: 7 WDL:      5 | 0 | 4 | 1 | 4
# Episode: 15/1000 Reward: 100 steps: 6 WDL:      6 | 0 | 4 | 1 | 4
# Episode: 16/1000 Reward: 100 steps: 8 WDL:      7 | 0 | 4 | 1 | 4
# Episode: 17/1000 Reward: -100 steps: 9 WDL:      7 | 0 | 5 | 1 | 4
# Episode: 18/1000 Reward: -100 steps: 9 WDL:      7 | 0 | 6 | 1 | 4
# Episode: 19/1000 Reward: 100 steps: 8 WDL:      8 | 0 | 6 | 1 | 4
# Episode: 20/1000 Reward: 100 steps: 8 WDL:      9 | 0 | 6 | 1 | 4
# Episode: 21/1000 Reward: 1000 steps: 7 WDL:      9 | 0 | 6 | 1 | 5
# Episode: 22/1000 Reward: 1000 steps: 9 WDL:      9 | 0 | 6 | 1 | 6
# Episode: 23/1000 Reward: -100 steps: 9 WDL:      9 | 0 | 7 | 1 | 6
# Episode: 24/1000 Reward: 100 steps: 6 WDL:      10 | 0 | 7 | 1 | 6
# Episode: 25/1000 Reward: 100 steps: 10 WDL:      11 | 0 | 7 | 1 | 6
# Episode: 26/1000 Reward: 1000 steps: 7 WDL:      11 | 0 | 7 | 1 | 7
# Episode: 27/1000 Reward: -100 steps: 9 WDL:      11 | 0 | 8 | 1 | 7
# Episode: 28/1000 Reward: -100 steps: 7 WDL:      11 | 0 | 9 | 1 | 7
# Episode: 29/1000 Reward: -1000 steps: 6 WDL:      11 | 0 | 9 | 2 | 7
# Episode: 30/1000 Reward: 100 steps: 6 WDL:      12 | 0 | 9 | 2 | 7
# Episode: 31/1000 Reward: -100 steps: 7 WDL:      12 | 0 | 10 | 2 | 7
# Episode: 32/1000 Reward: -1000 steps: 10 WDL:      12 | 0 | 10 | 3 | 7
# Episode: 33/1000 Reward: 100 steps: 6 WDL:      13 | 0 | 10 | 3 | 7
# Episode: 34/1000 Reward: -1000 steps: 8 WDL:      13 | 0 | 10 | 4 | 7
# Episode: 35/1000 Reward: -1000 steps: 6 WDL:      13 | 0 | 10 | 5 | 7
# Episode: 36/1000 Reward: 1000 steps: 7 WDL:      13 | 0 | 10 | 5 | 8
# Episode: 37/1000 Reward: 1000 steps: 7 WDL:      13 | 0 | 10 | 5 | 9
# Episode: 38/1000 Reward: 1000 steps: 13 WDL:      13 | 0 | 10 | 5 | 10
# Episode: 39/1000 Reward: 100 steps: 8 WDL:      14 | 0 | 10 | 5 | 10
# Episode: 40/1000 Reward: 100 steps: 8 WDL:      15 | 0 | 10 | 5 | 10
# Episode: 41/1000 Reward: 100 steps: 10 WDL:      16 | 0 | 10 | 5 | 10
# Episode: 42/1000 Reward: -100 steps: 7 WDL:      16 | 0 | 11 | 5 | 10
# Episode: 43/1000 Reward: -100 steps: 7 WDL:      16 | 0 | 12 | 5 | 10
# Episode: 44/1000 Reward: 100 steps: 8 WDL:      17 | 0 | 12 | 5 | 10
# Episode: 45/1000 Reward: -100 steps: 7 WDL:      17 | 0 | 13 | 5 | 10
# Episode: 46/1000 Reward: 100 steps: 6 WDL:      18 | 0 | 13 | 5 | 10
# Episode: 47/1000 Reward: -100 steps: 7 WDL:      18 | 0 | 14 | 5 | 10
# Episode: 48/1000 Reward: 100 steps: 8 WDL:      19 | 0 | 14 | 5 | 10
# Episode: 49/1000 Reward: -100 steps: 9 WDL:      19 | 0 | 15 | 5 | 10
# Episode: 50/1000 Reward: 100 steps: 8 WDL:      20 | 0 | 15 | 5 | 10
# Episode: 51/1000 Reward: 100 steps: 8 WDL:      21 | 0 | 15 | 5 | 10
# Episode: 52/1000 Reward: -100 steps: 7 WDL:      21 | 0 | 16 | 5 | 10
# Episode: 53/1000 Reward: 100 steps: 12 WDL:      22 | 0 | 16 | 5 | 10
# Episode: 54/1000 Reward: 100 steps: 6 WDL:      23 | 0 | 16 | 5 | 10
# Episode: 55/1000 Reward: 100 steps: 6 WDL:      24 | 0 | 16 | 5 | 10
# Episode: 56/1000 Reward: 100 steps: 6 WDL:      25 | 0 | 16 | 5 | 10
# Episode: 57/1000 Reward: -100 steps: 9 WDL:      25 | 0 | 17 | 5 | 10
# Episode: 58/1000 Reward: 100 steps: 6 WDL:      26 | 0 | 17 | 5 | 10
# Episode: 59/1000 Reward: -100 steps: 7 WDL:      26 | 0 | 18 | 5 | 10
# Episode: 60/1000 Reward: 100 steps: 6 WDL:      27 | 0 | 18 | 5 | 10
# Episode: 61/1000 Reward: -1000 steps: 10 WDL:      27 | 0 | 18 | 6 | 10
# Episode: 62/1000 Reward: -100 steps: 7 WDL:      27 | 0 | 19 | 6 | 10
# Episode: 63/1000 Reward: -100 steps: 11 WDL:      27 | 0 | 20 | 6 | 10
# Episode: 64/1000 Reward: -1000 steps: 14 WDL:      27 | 0 | 20 | 7 | 10
# Episode: 65/1000 Reward: 100 steps: 12 WDL:      28 | 0 | 20 | 7 | 10
# Episode: 66/1000 Reward: -100 steps: 9 WDL:      28 | 0 | 21 | 7 | 10
# Episode: 67/1000 Reward: 100 steps: 8 WDL:      29 | 0 | 21 | 7 | 10
# Episode: 68/1000 Reward: 100 steps: 6 WDL:      30 | 0 | 21 | 7 | 10
# Episode: 69/1000 Reward: -100 steps: 9 WDL:      30 | 0 | 22 | 7 | 10
# Episode: 70/1000 Reward: -100 steps: 7 WDL:      30 | 0 | 23 | 7 | 10
# Episode: 71/1000 Reward: 100 steps: 6 WDL:      31 | 0 | 23 | 7 | 10
# Episode: 72/1000 Reward: 100 steps: 12 WDL:      32 | 0 | 23 | 7 | 10
# Episode: 73/1000 Reward: 100 steps: 8 WDL:      33 | 0 | 23 | 7 | 10
# Episode: 74/1000 Reward: -100 steps: 7 WDL:      33 | 0 | 24 | 7 | 10
# Episode: 75/1000 Reward: 100 steps: 6 WDL:      34 | 0 | 24 | 7 | 10
# Episode: 76/1000 Reward: -100 steps: 11 WDL:      34 | 0 | 25 | 7 | 10
# Episode: 77/1000 Reward: 100 steps: 8 WDL:      35 | 0 | 25 | 7 | 10
# Episode: 78/1000 Reward: -100 steps: 7 WDL:      35 | 0 | 26 | 7 | 10
# Episode: 79/1000 Reward: 100 steps: 10 WDL:      36 | 0 | 26 | 7 | 10
# Episode: 80/1000 Reward: -100 steps: 9 WDL:      36 | 0 | 27 | 7 | 10
# Episode: 81/1000 Reward: 100 steps: 10 WDL:      37 | 0 | 27 | 7 | 10
# Episode: 82/1000 Reward: 100 steps: 6 WDL:      38 | 0 | 27 | 7 | 10
# Episode: 83/1000 Reward: 100 steps: 8 WDL:      39 | 0 | 27 | 7 | 10
# Episode: 84/1000 Reward: 100 steps: 6 WDL:      40 | 0 | 27 | 7 | 10
# Episode: 85/1000 Reward: -100 steps: 7 WDL:      40 | 0 | 28 | 7 | 10
# Episode: 86/1000 Reward: 100 steps: 6 WDL:      41 | 0 | 28 | 7 | 10
# Episode: 87/1000 Reward: 100 steps: 6 WDL:      42 | 0 | 28 | 7 | 10
# Episode: 88/1000 Reward: -100 steps: 7 WDL:      42 | 0 | 29 | 7 | 10
# Episode: 89/1000 Reward: 100 steps: 6 WDL:      43 | 0 | 29 | 7 | 10
# Episode: 90/1000 Reward: -100 steps: 11 WDL:      43 | 0 | 30 | 7 | 10
# Episode: 91/1000 Reward: -100 steps: 7 WDL:      43 | 0 | 31 | 7 | 10
# Episode: 92/1000 Reward: 100 steps: 8 WDL:      44 | 0 | 31 | 7 | 10
# Episode: 93/1000 Reward: -100 steps: 7 WDL:      44 | 0 | 32 | 7 | 10
# Episode: 94/1000 Reward: -100 steps: 7 WDL:      44 | 0 | 33 | 7 | 10
# Episode: 95/1000 Reward: 100 steps: 14 WDL:      45 | 0 | 33 | 7 | 10
# Episode: 96/1000 Reward: 100 steps: 6 WDL:      46 | 0 | 33 | 7 | 10
# Episode: 97/1000 Reward: 100 steps: 8 WDL:      47 | 0 | 33 | 7 | 10
# Episode: 98/1000 Reward: 100 steps: 8 WDL:      48 | 0 | 33 | 7 | 10
# Episode: 99/1000 Reward: -100 steps: 9 WDL:      48 | 0 | 34 | 7 | 10
# Episode: 100/1000 Reward: 100 steps: 8 WDL:      49 | 0 | 34 | 7 | 10
# Episode: 101/1000 Reward: 100 steps: 6 WDL:      50 | 0 | 34 | 7 | 10
# Episode: 102/1000 Reward: -100 steps: 7 WDL:      50 | 0 | 35 | 7 | 10
# Episode: 103/1000 Reward: 100 steps: 6 WDL:      51 | 0 | 35 | 7 | 10
# Episode: 104/1000 Reward: 100 steps: 6 WDL:      52 | 0 | 35 | 7 | 10
# Episode: 105/1000 Reward: 100 steps: 6 WDL:      53 | 0 | 35 | 7 | 10
# Episode: 106/1000 Reward: 100 steps: 6 WDL:      54 | 0 | 35 | 7 | 10
# Episode: 107/1000 Reward: -100 steps: 7 WDL:      54 | 0 | 36 | 7 | 10
# Episode: 108/1000 Reward: 100 steps: 6 WDL:      55 | 0 | 36 | 7 | 10
# Episode: 109/1000 Reward: 100 steps: 8 WDL:      56 | 0 | 36 | 7 | 10
# Episode: 110/1000 Reward: 100 steps: 8 WDL:      57 | 0 | 36 | 7 | 10
# Episode: 111/1000 Reward: 100 steps: 6 WDL:      58 | 0 | 36 | 7 | 10
# Episode: 112/1000 Reward: 100 steps: 12 WDL:      59 | 0 | 36 | 7 | 10
# Episode: 113/1000 Reward: 100 steps: 6 WDL:      60 | 0 | 36 | 7 | 10
# Episode: 114/1000 Reward: 1000 steps: 11 WDL:      60 | 0 | 36 | 7 | 11
# Episode: 115/1000 Reward: -100 steps: 9 WDL:      60 | 0 | 37 | 7 | 11
# Episode: 116/1000 Reward: 100 steps: 6 WDL:      61 | 0 | 37 | 7 | 11
# Episode: 117/1000 Reward: 100 steps: 6 WDL:      62 | 0 | 37 | 7 | 11
# Episode: 118/1000 Reward: 100 steps: 8 WDL:      63 | 0 | 37 | 7 | 11
# Episode: 119/1000 Reward: 100 steps: 6 WDL:      64 | 0 | 37 | 7 | 11
# Episode: 120/1000 Reward: -100 steps: 7 WDL:      64 | 0 | 38 | 7 | 11
# Episode: 121/1000 Reward: 100 steps: 10 WDL:      65 | 0 | 38 | 7 | 11
# Episode: 122/1000 Reward: -100 steps: 9 WDL:      65 | 0 | 39 | 7 | 11
# Episode: 123/1000 Reward: -100 steps: 9 WDL:      65 | 0 | 40 | 7 | 11
# Episode: 124/1000 Reward: -100 steps: 7 WDL:      65 | 0 | 41 | 7 | 11
# Episode: 125/1000 Reward: -1000 steps: 10 WDL:      65 | 0 | 41 | 8 | 11
# Episode: 126/1000 Reward: 100 steps: 6 WDL:      66 | 0 | 41 | 8 | 11
# Episode: 127/1000 Reward: -100 steps: 9 WDL:      66 | 0 | 42 | 8 | 11
# Episode: 128/1000 Reward: 1000 steps: 9 WDL:      66 | 0 | 42 | 8 | 12
# Episode: 129/1000 Reward: -100 steps: 7 WDL:      66 | 0 | 43 | 8 | 12
# Episode: 130/1000 Reward: 100 steps: 6 WDL:      67 | 0 | 43 | 8 | 12
# Episode: 131/1000 Reward: 100 steps: 6 WDL:      68 | 0 | 43 | 8 | 12
# Episode: 132/1000 Reward: -1000 steps: 12 WDL:      68 | 0 | 43 | 9 | 12
# Episode: 133/1000 Reward: 100 steps: 12 WDL:      69 | 0 | 43 | 9 | 12
# Episode: 134/1000 Reward: 100 steps: 8 WDL:      70 | 0 | 43 | 9 | 12
# Episode: 135/1000 Reward: 100 steps: 10 WDL:      71 | 0 | 43 | 9 | 12
# Episode: 136/1000 Reward: 100 steps: 6 WDL:      72 | 0 | 43 | 9 | 12
# Episode: 137/1000 Reward: -100 steps: 7 WDL:      72 | 0 | 44 | 9 | 12
# Episode: 138/1000 Reward: -100 steps: 7 WDL:      72 | 0 | 45 | 9 | 12
# Episode: 139/1000 Reward: 100 steps: 12 WDL:      73 | 0 | 45 | 9 | 12
# Episode: 140/1000 Reward: -100 steps: 7 WDL:      73 | 0 | 46 | 9 | 12
# Episode: 141/1000 Reward: -100 steps: 9 WDL:      73 | 0 | 47 | 9 | 12
# Episode: 142/1000 Reward: -100 steps: 11 WDL:      73 | 0 | 48 | 9 | 12
# Episode: 143/1000 Reward: 100 steps: 12 WDL:      74 | 0 | 48 | 9 | 12
# Episode: 144/1000 Reward: 100 steps: 8 WDL:      75 | 0 | 48 | 9 | 12
# Episode: 145/1000 Reward: 100 steps: 6 WDL:      76 | 0 | 48 | 9 | 12
# Episode: 146/1000 Reward: 100 steps: 8 WDL:      77 | 0 | 48 | 9 | 12
# Episode: 147/1000 Reward: 100 steps: 6 WDL:      78 | 0 | 48 | 9 | 12
# Episode: 148/1000 Reward: 100 steps: 6 WDL:      79 | 0 | 48 | 9 | 12
# Episode: 149/1000 Reward: -100 steps: 13 WDL:      79 | 0 | 49 | 9 | 12
# Episode: 150/1000 Reward: -1000 steps: 12 WDL:      79 | 0 | 49 | 10 | 12
# Episode: 151/1000 Reward: -100 steps: 7 WDL:      79 | 0 | 50 | 10 | 12
# Episode: 152/1000 Reward: 100 steps: 16 WDL:      80 | 0 | 50 | 10 | 12
# Episode: 153/1000 Reward: -100 steps: 7 WDL:      80 | 0 | 51 | 10 | 12
# Episode: 154/1000 Reward: 1000 steps: 11 WDL:      80 | 0 | 51 | 10 | 13
# Episode: 155/1000 Reward: 100 steps: 6 WDL:      81 | 0 | 51 | 10 | 13
# Episode: 156/1000 Reward: 100 steps: 14 WDL:      82 | 0 | 51 | 10 | 13
# Episode: 157/1000 Reward: 100 steps: 6 WDL:      83 | 0 | 51 | 10 | 13
# Episode: 158/1000 Reward: -100 steps: 9 WDL:      83 | 0 | 52 | 10 | 13
# Episode: 159/1000 Reward: -100 steps: 7 WDL:      83 | 0 | 53 | 10 | 13
# Episode: 160/1000 Reward: 100 steps: 8 WDL:      84 | 0 | 53 | 10 | 13
# Episode: 161/1000 Reward: 100 steps: 10 WDL:      85 | 0 | 53 | 10 | 13
# Episode: 162/1000 Reward: 1000 steps: 15 WDL:      85 | 0 | 53 | 10 | 14
# Episode: 163/1000 Reward: 100 steps: 18 WDL:      86 | 0 | 53 | 10 | 14
# Episode: 164/1000 Reward: -100 steps: 13 WDL:      86 | 0 | 54 | 10 | 14
# Episode: 165/1000 Reward: 100 steps: 6 WDL:      87 | 0 | 54 | 10 | 14
# Episode: 166/1000 Reward: -100 steps: 7 WDL:      87 | 0 | 55 | 10 | 14
# Episode: 167/1000 Reward: -100 steps: 15 WDL:      87 | 0 | 56 | 10 | 14
# Episode: 168/1000 Reward: 100 steps: 12 WDL:      88 | 0 | 56 | 10 | 14
# Episode: 169/1000 Reward: -1000 steps: 12 WDL:      88 | 0 | 56 | 11 | 14
# Episode: 170/1000 Reward: 1000 steps: 13 WDL:      88 | 0 | 56 | 11 | 15
# Episode: 171/1000 Reward: 100 steps: 10 WDL:      89 | 0 | 56 | 11 | 15
# Episode: 172/1000 Reward: -100 steps: 7 WDL:      89 | 0 | 57 | 11 | 15
# Episode: 173/1000 Reward: 1000 steps: 15 WDL:      89 | 0 | 57 | 11 | 16
# Episode: 174/1000 Reward: 100 steps: 16 WDL:      90 | 0 | 57 | 11 | 16
# Episode: 175/1000 Reward: -100 steps: 7 WDL:      90 | 0 | 58 | 11 | 16
# Episode: 176/1000 Reward: 100 steps: 14 WDL:      91 | 0 | 58 | 11 | 16
# Episode: 177/1000 Reward: -100 steps: 9 WDL:      91 | 0 | 59 | 11 | 16
# Episode: 178/1000 Reward: -100 steps: 7 WDL:      91 | 0 | 60 | 11 | 16
# Episode: 179/1000 Reward: -100 steps: 9 WDL:      91 | 0 | 61 | 11 | 16
# Episode: 180/1000 Reward: -100 steps: 9 WDL:      91 | 0 | 62 | 11 | 16
# Episode: 181/1000 Reward: 100 steps: 8 WDL:      92 | 0 | 62 | 11 | 16
# Episode: 182/1000 Reward: -100 steps: 7 WDL:      92 | 0 | 63 | 11 | 16
# Episode: 183/1000 Reward: 1000 steps: 15 WDL:      92 | 0 | 63 | 11 | 17
# Episode: 184/1000 Reward: 1000 steps: 15 WDL:      92 | 0 | 63 | 11 | 18
# Episode: 185/1000 Reward: -1000 steps: 10 WDL:      92 | 0 | 63 | 12 | 18
# Episode: 186/1000 Reward: 1000 steps: 13 WDL:      92 | 0 | 63 | 12 | 19
# Episode: 187/1000 Reward: -1000 steps: 14 WDL:      92 | 0 | 63 | 13 | 19
# Episode: 188/1000 Reward: 1000 steps: 11 WDL:      92 | 0 | 63 | 13 | 20
# Episode: 189/1000 Reward: 100 steps: 12 WDL:      93 | 0 | 63 | 13 | 20
# Episode: 190/1000 Reward: -1000 steps: 10 WDL:      93 | 0 | 63 | 14 | 20
# Episode: 191/1000 Reward: -100 steps: 7 WDL:      93 | 0 | 64 | 14 | 20
# Episode: 192/1000 Reward: -1000 steps: 12 WDL:      93 | 0 | 64 | 15 | 20
# Episode: 193/1000 Reward: 1000 steps: 13 WDL:      93 | 0 | 64 | 15 | 21
# Episode: 194/1000 Reward: 100 steps: 10 WDL:      94 | 0 | 64 | 15 | 21
# Episode: 195/1000 Reward: -100 steps: 11 WDL:      94 | 0 | 65 | 15 | 21
# Episode: 196/1000 Reward: 1000 steps: 13 WDL:      94 | 0 | 65 | 15 | 22
# Episode: 197/1000 Reward: 100 steps: 8 WDL:      95 | 0 | 65 | 15 | 22
# Episode: 198/1000 Reward: -100 steps: 9 WDL:      95 | 0 | 66 | 15 | 22
# Episode: 199/1000 Reward: -100 steps: 13 WDL:      95 | 0 | 67 | 15 | 22
# Episode: 200/1000 Reward: -100 steps: 17 WDL:      95 | 0 | 68 | 15 | 22
# Episode: 201/1000 Reward: 100 steps: 12 WDL:      96 | 0 | 68 | 15 | 22
# Episode: 202/1000 Reward: -100 steps: 7 WDL:      96 | 0 | 69 | 15 | 22
# Episode: 203/1000 Reward: 100 steps: 12 WDL:      97 | 0 | 69 | 15 | 22
# Episode: 204/1000 Reward: 100 steps: 12 WDL:      98 | 0 | 69 | 15 | 22
# Episode: 205/1000 Reward: 100 steps: 10 WDL:      99 | 0 | 69 | 15 | 22
# Episode: 206/1000 Reward: 1000 steps: 21 WDL:      99 | 0 | 69 | 15 | 23
# Episode: 207/1000 Reward: 1000 steps: 15 WDL:      99 | 0 | 69 | 15 | 24
# Episode: 208/1000 Reward: -100 steps: 9 WDL:      99 | 0 | 70 | 15 | 24
# Episode: 209/1000 Reward: -1000 steps: 12 WDL:      99 | 0 | 70 | 16 | 24
# Episode: 210/1000 Reward: 100 steps: 10 WDL:      100 | 0 | 70 | 16 | 24
# Episode: 211/1000 Reward: -1000 steps: 12 WDL:      100 | 0 | 70 | 17 | 24
# Episode: 212/1000 Reward: -100 steps: 13 WDL:      100 | 0 | 71 | 17 | 24
# Episode: 213/1000 Reward: -100 steps: 7 WDL:      100 | 0 | 72 | 17 | 24
# Episode: 214/1000 Reward: -100 steps: 11 WDL:      100 | 0 | 73 | 17 | 24
# Episode: 215/1000 Reward: -1000 steps: 10 WDL:      100 | 0 | 73 | 18 | 24
# Episode: 216/1000 Reward: 100 steps: 10 WDL:      101 | 0 | 73 | 18 | 24
# Episode: 217/1000 Reward: -100 steps: 13 WDL:      101 | 0 | 74 | 18 | 24
# Episode: 218/1000 Reward: 100 steps: 14 WDL:      102 | 0 | 74 | 18 | 24
# Episode: 219/1000 Reward: -100 steps: 7 WDL:      102 | 0 | 75 | 18 | 24
# Episode: 220/1000 Reward: -100 steps: 7 WDL:      102 | 0 | 76 | 18 | 24
# Episode: 221/1000 Reward: -100 steps: 15 WDL:      102 | 0 | 77 | 18 | 24
# Episode: 222/1000 Reward: -100 steps: 9 WDL:      102 | 0 | 78 | 18 | 24
# Episode: 223/1000 Reward: -100 steps: 7 WDL:      102 | 0 | 79 | 18 | 24
# Episode: 224/1000 Reward: 100 steps: 10 WDL:      103 | 0 | 79 | 18 | 24
# Episode: 225/1000 Reward: -100 steps: 11 WDL:      103 | 0 | 80 | 18 | 24
# Episode: 226/1000 Reward: 100 steps: 10 WDL:      104 | 0 | 80 | 18 | 24
# Episode: 227/1000 Reward: 100 steps: 18 WDL:      105 | 0 | 80 | 18 | 24
# Episode: 228/1000 Reward: 1000 steps: 17 WDL:      105 | 0 | 80 | 18 | 25
# Episode: 229/1000 Reward: 100 steps: 10 WDL:      106 | 0 | 80 | 18 | 25
# Episode: 230/1000 Reward: -100 steps: 9 WDL:      106 | 0 | 81 | 18 | 25
# Episode: 231/1000 Reward: -100 steps: 7 WDL:      106 | 0 | 82 | 18 | 25
# Episode: 232/1000 Reward: -100 steps: 15 WDL:      106 | 0 | 83 | 18 | 25
# Episode: 233/1000 Reward: 100 steps: 12 WDL:      107 | 0 | 83 | 18 | 25
# Episode: 234/1000 Reward: 100 steps: 8 WDL:      108 | 0 | 83 | 18 | 25
# Episode: 235/1000 Reward: 100 steps: 6 WDL:      109 | 0 | 83 | 18 | 25
# Episode: 236/1000 Reward: 100 steps: 6 WDL:      110 | 0 | 83 | 18 | 25
# Episode: 237/1000 Reward: 100 steps: 8 WDL:      111 | 0 | 83 | 18 | 25
# Episode: 238/1000 Reward: 100 steps: 6 WDL:      112 | 0 | 83 | 18 | 25
# Episode: 239/1000 Reward: 100 steps: 6 WDL:      113 | 0 | 83 | 18 | 25
# Episode: 240/1000 Reward: 100 steps: 6 WDL:      114 | 0 | 83 | 18 | 25
# Episode: 241/1000 Reward: -100 steps: 7 WDL:      114 | 0 | 84 | 18 | 25
# Episode: 242/1000 Reward: 100 steps: 6 WDL:      115 | 0 | 84 | 18 | 25
# Episode: 243/1000 Reward: 100 steps: 6 WDL:      116 | 0 | 84 | 18 | 25
# Episode: 244/1000 Reward: 100 steps: 10 WDL:      117 | 0 | 84 | 18 | 25
# Episode: 245/1000 Reward: 100 steps: 6 WDL:      118 | 0 | 84 | 18 | 25
# Episode: 246/1000 Reward: 100 steps: 6 WDL:      119 | 0 | 84 | 18 | 25
# Episode: 247/1000 Reward: -100 steps: 7 WDL:      119 | 0 | 85 | 18 | 25
# Episode: 248/1000 Reward: 100 steps: 8 WDL:      120 | 0 | 85 | 18 | 25
# Episode: 249/1000 Reward: 100 steps: 6 WDL:      121 | 0 | 85 | 18 | 25
# Episode: 250/1000 Reward: -1000 steps: 12 WDL:      121 | 0 | 85 | 19 | 25
# Episode: 251/1000 Reward: -100 steps: 7 WDL:      121 | 0 | 86 | 19 | 25
# Episode: 252/1000 Reward: -100 steps: 9 WDL:      121 | 0 | 87 | 19 | 25
# Episode: 253/1000 Reward: -100 steps: 9 WDL:      121 | 0 | 88 | 19 | 25
# Episode: 254/1000 Reward: 100 steps: 6 WDL:      122 | 0 | 88 | 19 | 25
# Episode: 255/1000 Reward: 100 steps: 8 WDL:      123 | 0 | 88 | 19 | 25
# Episode: 256/1000 Reward: -100 steps: 7 WDL:      123 | 0 | 89 | 19 | 25
# Episode: 257/1000 Reward: -100 steps: 7 WDL:      123 | 0 | 90 | 19 | 25
# Episode: 258/1000 Reward: 100 steps: 8 WDL:      124 | 0 | 90 | 19 | 25
# Episode: 259/1000 Reward: 100 steps: 6 WDL:      125 | 0 | 90 | 19 | 25
# Episode: 260/1000 Reward: 100 steps: 6 WDL:      126 | 0 | 90 | 19 | 25
# Episode: 261/1000 Reward: 100 steps: 6 WDL:      127 | 0 | 90 | 19 | 25
# Episode: 262/1000 Reward: -100 steps: 7 WDL:      127 | 0 | 91 | 19 | 25
# Episode: 263/1000 Reward: -100 steps: 9 WDL:      127 | 0 | 92 | 19 | 25
# Episode: 264/1000 Reward: 1000 steps: 19 WDL:      127 | 0 | 92 | 19 | 26
# Episode: 265/1000 Reward: 100 steps: 6 WDL:      128 | 0 | 92 | 19 | 26
# Episode: 266/1000 Reward: -100 steps: 7 WDL:      128 | 0 | 93 | 19 | 26
# Episode: 267/1000 Reward: 100 steps: 8 WDL:      129 | 0 | 93 | 19 | 26
# Episode: 268/1000 Reward: -100 steps: 7 WDL:      129 | 0 | 94 | 19 | 26
# Episode: 269/1000 Reward: 100 steps: 6 WDL:      130 | 0 | 94 | 19 | 26
# Episode: 270/1000 Reward: 100 steps: 8 WDL:      131 | 0 | 94 | 19 | 26
# Episode: 271/1000 Reward: 100 steps: 6 WDL:      132 | 0 | 94 | 19 | 26
# Episode: 272/1000 Reward: 100 steps: 10 WDL:      133 | 0 | 94 | 19 | 26
# Episode: 273/1000 Reward: 100 steps: 8 WDL:      134 | 0 | 94 | 19 | 26
# Episode: 274/1000 Reward: 100 steps: 6 WDL:      135 | 0 | 94 | 19 | 26
# Episode: 275/1000 Reward: -100 steps: 13 WDL:      135 | 0 | 95 | 19 | 26
# Episode: 276/1000 Reward: 100 steps: 6 WDL:      136 | 0 | 95 | 19 | 26
# Episode: 277/1000 Reward: 100 steps: 8 WDL:      137 | 0 | 95 | 19 | 26
# Episode: 278/1000 Reward: 100 steps: 6 WDL:      138 | 0 | 95 | 19 | 26
# Episode: 279/1000 Reward: -100 steps: 7 WDL:      138 | 0 | 96 | 19 | 26
# Episode: 280/1000 Reward: 100 steps: 6 WDL:      139 | 0 | 96 | 19 | 26
# Episode: 281/1000 Reward: 100 steps: 8 WDL:      140 | 0 | 96 | 19 | 26
# Episode: 282/1000 Reward: 100 steps: 6 WDL:      141 | 0 | 96 | 19 | 26
# Episode: 283/1000 Reward: 100 steps: 8 WDL:      142 | 0 | 96 | 19 | 26
# Episode: 284/1000 Reward: -100 steps: 7 WDL:      142 | 0 | 97 | 19 | 26
# Episode: 285/1000 Reward: 100 steps: 6 WDL:      143 | 0 | 97 | 19 | 26
# Episode: 286/1000 Reward: 100 steps: 6 WDL:      144 | 0 | 97 | 19 | 26
# Episode: 287/1000 Reward: 100 steps: 6 WDL:      145 | 0 | 97 | 19 | 26
# Episode: 288/1000 Reward: 100 steps: 6 WDL:      146 | 0 | 97 | 19 | 26
# Episode: 289/1000 Reward: 100 steps: 6 WDL:      147 | 0 | 97 | 19 | 26
# Episode: 290/1000 Reward: 100 steps: 6 WDL:      148 | 0 | 97 | 19 | 26
# Episode: 291/1000 Reward: 100 steps: 8 WDL:      149 | 0 | 97 | 19 | 26
# Episode: 292/1000 Reward: -100 steps: 9 WDL:      149 | 0 | 98 | 19 | 26
# Episode: 293/1000 Reward: -100 steps: 9 WDL:      149 | 0 | 99 | 19 | 26
# Episode: 294/1000 Reward: 100 steps: 6 WDL:      150 | 0 | 99 | 19 | 26
# Episode: 295/1000 Reward: -100 steps: 7 WDL:      150 | 0 | 100 | 19 | 26
# Episode: 296/1000 Reward: -1000 steps: 16 WDL:      150 | 0 | 100 | 20 | 26
# Episode: 297/1000 Reward: 100 steps: 6 WDL:      151 | 0 | 100 | 20 | 26
# Episode: 298/1000 Reward: 100 steps: 10 WDL:      152 | 0 | 100 | 20 | 26
# Episode: 299/1000 Reward: 100 steps: 8 WDL:      153 | 0 | 100 | 20 | 26
# Episode: 300/1000 Reward: -100 steps: 7 WDL:      153 | 0 | 101 | 20 | 26
# Episode: 301/1000 Reward: 100 steps: 6 WDL:      154 | 0 | 101 | 20 | 26
# Episode: 302/1000 Reward: -100 steps: 7 WDL:      154 | 0 | 102 | 20 | 26
# Episode: 303/1000 Reward: 100 steps: 6 WDL:      155 | 0 | 102 | 20 | 26
# Episode: 304/1000 Reward: 100 steps: 6 WDL:      156 | 0 | 102 | 20 | 26
# Episode: 305/1000 Reward: -1000 steps: 10 WDL:      156 | 0 | 102 | 21 | 26
# Episode: 306/1000 Reward: 100 steps: 6 WDL:      157 | 0 | 102 | 21 | 26
# Episode: 307/1000 Reward: 100 steps: 8 WDL:      158 | 0 | 102 | 21 | 26
# Episode: 308/1000 Reward: 100 steps: 6 WDL:      159 | 0 | 102 | 21 | 26
# Episode: 309/1000 Reward: 100 steps: 6 WDL:      160 | 0 | 102 | 21 | 26
# Episode: 310/1000 Reward: -100 steps: 7 WDL:      160 | 0 | 103 | 21 | 26
# Episode: 311/1000 Reward: 100 steps: 6 WDL:      161 | 0 | 103 | 21 | 26
# Episode: 312/1000 Reward: 100 steps: 8 WDL:      162 | 0 | 103 | 21 | 26
# Episode: 313/1000 Reward: -1000 steps: 10 WDL:      162 | 0 | 103 | 22 | 26
# Episode: 314/1000 Reward: 100 steps: 8 WDL:      163 | 0 | 103 | 22 | 26
# Episode: 315/1000 Reward: -100 steps: 7 WDL:      163 | 0 | 104 | 22 | 26
# Episode: 316/1000 Reward: 100 steps: 6 WDL:      164 | 0 | 104 | 22 | 26
# Episode: 317/1000 Reward: 100 steps: 6 WDL:      165 | 0 | 104 | 22 | 26
# Episode: 318/1000 Reward: 100 steps: 8 WDL:      166 | 0 | 104 | 22 | 26
# Episode: 319/1000 Reward: 100 steps: 8 WDL:      167 | 0 | 104 | 22 | 26
# Episode: 320/1000 Reward: 100 steps: 6 WDL:      168 | 0 | 104 | 22 | 26
# Episode: 321/1000 Reward: -100 steps: 7 WDL:      168 | 0 | 105 | 22 | 26
# Episode: 322/1000 Reward: 100 steps: 10 WDL:      169 | 0 | 105 | 22 | 26
# Episode: 323/1000 Reward: 100 steps: 8 WDL:      170 | 0 | 105 | 22 | 26
# Episode: 324/1000 Reward: -100 steps: 13 WDL:      170 | 0 | 106 | 22 | 26
# Episode: 325/1000 Reward: -100 steps: 9 WDL:      170 | 0 | 107 | 22 | 26
# Episode: 326/1000 Reward: -100 steps: 7 WDL:      170 | 0 | 108 | 22 | 26
# Episode: 327/1000 Reward: 100 steps: 6 WDL:      171 | 0 | 108 | 22 | 26
# Episode: 328/1000 Reward: 100 steps: 8 WDL:      172 | 0 | 108 | 22 | 26
# Episode: 329/1000 Reward: -100 steps: 7 WDL:      172 | 0 | 109 | 22 | 26
# Episode: 330/1000 Reward: -100 steps: 7 WDL:      172 | 0 | 110 | 22 | 26
# Episode: 331/1000 Reward: 100 steps: 6 WDL:      173 | 0 | 110 | 22 | 26
# Episode: 332/1000 Reward: 100 steps: 6 WDL:      174 | 0 | 110 | 22 | 26
# Episode: 333/1000 Reward: 100 steps: 6 WDL:      175 | 0 | 110 | 22 | 26
# Episode: 334/1000 Reward: 100 steps: 8 WDL:      176 | 0 | 110 | 22 | 26
# Episode: 335/1000 Reward: 100 steps: 8 WDL:      177 | 0 | 110 | 22 | 26
# Episode: 336/1000 Reward: 100 steps: 6 WDL:      178 | 0 | 110 | 22 | 26
# Episode: 337/1000 Reward: 100 steps: 6 WDL:      179 | 0 | 110 | 22 | 26
# Episode: 338/1000 Reward: -100 steps: 9 WDL:      179 | 0 | 111 | 22 | 26
# Episode: 339/1000 Reward: 100 steps: 10 WDL:      180 | 0 | 111 | 22 | 26
# Episode: 340/1000 Reward: 100 steps: 6 WDL:      181 | 0 | 111 | 22 | 26
# Episode: 341/1000 Reward: 100 steps: 6 WDL:      182 | 0 | 111 | 22 | 26
# Episode: 342/1000 Reward: -100 steps: 7 WDL:      182 | 0 | 112 | 22 | 26
# Episode: 343/1000 Reward: 100 steps: 6 WDL:      183 | 0 | 112 | 22 | 26
# Episode: 344/1000 Reward: 100 steps: 6 WDL:      184 | 0 | 112 | 22 | 26
# Episode: 345/1000 Reward: -100 steps: 7 WDL:      184 | 0 | 113 | 22 | 26
# Episode: 346/1000 Reward: 100 steps: 6 WDL:      185 | 0 | 113 | 22 | 26
# Episode: 347/1000 Reward: 100 steps: 6 WDL:      186 | 0 | 113 | 22 | 26
# Episode: 348/1000 Reward: -1000 steps: 12 WDL:      186 | 0 | 113 | 23 | 26
# Episode: 349/1000 Reward: -100 steps: 7 WDL:      186 | 0 | 114 | 23 | 26
# Episode: 350/1000 Reward: 100 steps: 6 WDL:      187 | 0 | 114 | 23 | 26
# Episode: 351/1000 Reward: -1000 steps: 12 WDL:      187 | 0 | 114 | 24 | 26
# Episode: 352/1000 Reward: -100 steps: 7 WDL:      187 | 0 | 115 | 24 | 26
# Episode: 353/1000 Reward: 100 steps: 6 WDL:      188 | 0 | 115 | 24 | 26
# Episode: 354/1000 Reward: 100 steps: 6 WDL:      189 | 0 | 115 | 24 | 26
# Episode: 355/1000 Reward: 100 steps: 6 WDL:      190 | 0 | 115 | 24 | 26
# Episode: 356/1000 Reward: 100 steps: 6 WDL:      191 | 0 | 115 | 24 | 26
# Episode: 357/1000 Reward: -100 steps: 7 WDL:      191 | 0 | 116 | 24 | 26
# Episode: 358/1000 Reward: -100 steps: 7 WDL:      191 | 0 | 117 | 24 | 26
# Episode: 359/1000 Reward: 100 steps: 8 WDL:      192 | 0 | 117 | 24 | 26
# Episode: 360/1000 Reward: 100 steps: 6 WDL:      193 | 0 | 117 | 24 | 26
# Episode: 361/1000 Reward: -100 steps: 7 WDL:      193 | 0 | 118 | 24 | 26
# Episode: 362/1000 Reward: 100 steps: 6 WDL:      194 | 0 | 118 | 24 | 26
# Episode: 363/1000 Reward: 100 steps: 6 WDL:      195 | 0 | 118 | 24 | 26
# Episode: 364/1000 Reward: 100 steps: 6 WDL:      196 | 0 | 118 | 24 | 26
# Episode: 365/1000 Reward: -100 steps: 7 WDL:      196 | 0 | 119 | 24 | 26
# Episode: 366/1000 Reward: 100 steps: 6 WDL:      197 | 0 | 119 | 24 | 26
# Episode: 367/1000 Reward: -100 steps: 7 WDL:      197 | 0 | 120 | 24 | 26
# Episode: 368/1000 Reward: 100 steps: 6 WDL:      198 | 0 | 120 | 24 | 26
# Episode: 369/1000 Reward: 100 steps: 6 WDL:      199 | 0 | 120 | 24 | 26
# Episode: 370/1000 Reward: 1000 steps: 13 WDL:      199 | 0 | 120 | 24 | 27
# Episode: 371/1000 Reward: -100 steps: 7 WDL:      199 | 0 | 121 | 24 | 27
# Episode: 372/1000 Reward: -100 steps: 11 WDL:      199 | 0 | 122 | 24 | 27
# Episode: 373/1000 Reward: 100 steps: 6 WDL:      200 | 0 | 122 | 24 | 27
# Episode: 374/1000 Reward: -100 steps: 11 WDL:      200 | 0 | 123 | 24 | 27
# Episode: 375/1000 Reward: 100 steps: 10 WDL:      201 | 0 | 123 | 24 | 27
# Episode: 376/1000 Reward: -100 steps: 11 WDL:      201 | 0 | 124 | 24 | 27
# Episode: 377/1000 Reward: 100 steps: 10 WDL:      202 | 0 | 124 | 24 | 27
# Episode: 378/1000 Reward: 100 steps: 6 WDL:      203 | 0 | 124 | 24 | 27
# Episode: 379/1000 Reward: -100 steps: 7 WDL:      203 | 0 | 125 | 24 | 27
# Episode: 380/1000 Reward: 100 steps: 6 WDL:      204 | 0 | 125 | 24 | 27
# Episode: 381/1000 Reward: 100 steps: 8 WDL:      205 | 0 | 125 | 24 | 27
# Episode: 382/1000 Reward: 100 steps: 6 WDL:      206 | 0 | 125 | 24 | 27
# Episode: 383/1000 Reward: 100 steps: 8 WDL:      207 | 0 | 125 | 24 | 27
# Episode: 384/1000 Reward: 100 steps: 8 WDL:      208 | 0 | 125 | 24 | 27
# Episode: 385/1000 Reward: 100 steps: 8 WDL:      209 | 0 | 125 | 24 | 27
# Episode: 386/1000 Reward: 100 steps: 6 WDL:      210 | 0 | 125 | 24 | 27
# Episode: 387/1000 Reward: 100 steps: 6 WDL:      211 | 0 | 125 | 24 | 27
# Episode: 388/1000 Reward: 100 steps: 6 WDL:      212 | 0 | 125 | 24 | 27
# Episode: 389/1000 Reward: 100 steps: 6 WDL:      213 | 0 | 125 | 24 | 27
# Episode: 390/1000 Reward: 100 steps: 6 WDL:      214 | 0 | 125 | 24 | 27
# Episode: 391/1000 Reward: -1000 steps: 12 WDL:      214 | 0 | 125 | 25 | 27
# Episode: 392/1000 Reward: -100 steps: 9 WDL:      214 | 0 | 126 | 25 | 27
# Episode: 393/1000 Reward: -100 steps: 7 WDL:      214 | 0 | 127 | 25 | 27
# Episode: 394/1000 Reward: -100 steps: 7 WDL:      214 | 0 | 128 | 25 | 27
# Episode: 395/1000 Reward: -100 steps: 7 WDL:      214 | 0 | 129 | 25 | 27
# Episode: 396/1000 Reward: 100 steps: 6 WDL:      215 | 0 | 129 | 25 | 27
# Episode: 397/1000 Reward: 100 steps: 6 WDL:      216 | 0 | 129 | 25 | 27
# Episode: 398/1000 Reward: -100 steps: 7 WDL:      216 | 0 | 130 | 25 | 27
# Episode: 399/1000 Reward: 100 steps: 6 WDL:      217 | 0 | 130 | 25 | 27
# Episode: 400/1000 Reward: -100 steps: 15 WDL:      217 | 0 | 131 | 25 | 27
# Episode: 401/1000 Reward: -100 steps: 11 WDL:      217 | 0 | 132 | 25 | 27
# Episode: 402/1000 Reward: -100 steps: 11 WDL:      217 | 0 | 133 | 25 | 27
# Episode: 403/1000 Reward: -100 steps: 7 WDL:      217 | 0 | 134 | 25 | 27
# Episode: 404/1000 Reward: -100 steps: 9 WDL:      217 | 0 | 135 | 25 | 27
# Episode: 405/1000 Reward: -100 steps: 9 WDL:      217 | 0 | 136 | 25 | 27
# Episode: 406/1000 Reward: -100 steps: 9 WDL:      217 | 0 | 137 | 25 | 27
# Episode: 407/1000 Reward: 100 steps: 14 WDL:      218 | 0 | 137 | 25 | 27
# Episode: 408/1000 Reward: -100 steps: 11 WDL:      218 | 0 | 138 | 25 | 27
# Episode: 409/1000 Reward: -100 steps: 9 WDL:      218 | 0 | 139 | 25 | 27
# Episode: 410/1000 Reward: 1000 steps: 17 WDL:      218 | 0 | 139 | 25 | 28
# Episode: 411/1000 Reward: 100 steps: 10 WDL:      219 | 0 | 139 | 25 | 28
# Episode: 412/1000 Reward: 100 steps: 6 WDL:      220 | 0 | 139 | 25 | 28
# Episode: 413/1000 Reward: -100 steps: 9 WDL:      220 | 0 | 140 | 25 | 28
# Episode: 414/1000 Reward: 100 steps: 10 WDL:      221 | 0 | 140 | 25 | 28
# Episode: 415/1000 Reward: -100 steps: 17 WDL:      221 | 0 | 141 | 25 | 28
# Episode: 416/1000 Reward: 1000 steps: 17 WDL:      221 | 0 | 141 | 25 | 29
# Episode: 417/1000 Reward: -100 steps: 9 WDL:      221 | 0 | 142 | 25 | 29
# Episode: 418/1000 Reward: 1000 steps: 19 WDL:      221 | 0 | 142 | 25 | 30
# Episode: 419/1000 Reward: -100 steps: 7 WDL:      221 | 0 | 143 | 25 | 30
# Episode: 420/1000 Reward: -100 steps: 9 WDL:      221 | 0 | 144 | 25 | 30
# Episode: 421/1000 Reward: -100 steps: 7 WDL:      221 | 0 | 145 | 25 | 30
# Episode: 422/1000 Reward: 100 steps: 8 WDL:      222 | 0 | 145 | 25 | 30
# Episode: 423/1000 Reward: 1000 steps: 13 WDL:      222 | 0 | 145 | 25 | 31
# Episode: 424/1000 Reward: -100 steps: 11 WDL:      222 | 0 | 146 | 25 | 31
# Episode: 425/1000 Reward: -100 steps: 9 WDL:      222 | 0 | 147 | 25 | 31
# Episode: 426/1000 Reward: -100 steps: 9 WDL:      222 | 0 | 148 | 25 | 31
# Episode: 427/1000 Reward: 100 steps: 6 WDL:      223 | 0 | 148 | 25 | 31
# Episode: 428/1000 Reward: 100 steps: 6 WDL:      224 | 0 | 148 | 25 | 31
# Episode: 429/1000 Reward: 100 steps: 6 WDL:      225 | 0 | 148 | 25 | 31
# Episode: 430/1000 Reward: 100 steps: 12 WDL:      226 | 0 | 148 | 25 | 31
# Episode: 431/1000 Reward: 100 steps: 6 WDL:      227 | 0 | 148 | 25 | 31
# Episode: 432/1000 Reward: 100 steps: 6 WDL:      228 | 0 | 148 | 25 | 31
# Episode: 433/1000 Reward: 100 steps: 6 WDL:      229 | 0 | 148 | 25 | 31
# Episode: 434/1000 Reward: 100 steps: 12 WDL:      230 | 0 | 148 | 25 | 31
# Episode: 435/1000 Reward: 100 steps: 6 WDL:      231 | 0 | 148 | 25 | 31
# Episode: 436/1000 Reward: 100 steps: 6 WDL:      232 | 0 | 148 | 25 | 31
# Episode: 437/1000 Reward: 100 steps: 6 WDL:      233 | 0 | 148 | 25 | 31
# Episode: 438/1000 Reward: 100 steps: 6 WDL:      234 | 0 | 148 | 25 | 31
# Episode: 439/1000 Reward: 100 steps: 6 WDL:      235 | 0 | 148 | 25 | 31
# Episode: 440/1000 Reward: -1000 steps: 20 WDL:      235 | 0 | 148 | 26 | 31
# Episode: 441/1000 Reward: -100 steps: 17 WDL:      235 | 0 | 149 | 26 | 31
# Episode: 442/1000 Reward: 100 steps: 22 WDL:      236 | 0 | 149 | 26 | 31
# Episode: 443/1000 Reward: 100 steps: 6 WDL:      237 | 0 | 149 | 26 | 31
# Episode: 444/1000 Reward: 100 steps: 8 WDL:      238 | 0 | 149 | 26 | 31
# Episode: 445/1000 Reward: -100 steps: 7 WDL:      238 | 0 | 150 | 26 | 31
# Episode: 446/1000 Reward: 100 steps: 6 WDL:      239 | 0 | 150 | 26 | 31
# Episode: 447/1000 Reward: 100 steps: 6 WDL:      240 | 0 | 150 | 26 | 31
# Episode: 448/1000 Reward: 100 steps: 8 WDL:      241 | 0 | 150 | 26 | 31
# Episode: 449/1000 Reward: 100 steps: 6 WDL:      242 | 0 | 150 | 26 | 31
# Episode: 450/1000 Reward: 100 steps: 6 WDL:      243 | 0 | 150 | 26 | 31
# Episode: 451/1000 Reward: -100 steps: 7 WDL:      243 | 0 | 151 | 26 | 31
# Episode: 452/1000 Reward: 100 steps: 6 WDL:      244 | 0 | 151 | 26 | 31
# Episode: 453/1000 Reward: 100 steps: 6 WDL:      245 | 0 | 151 | 26 | 31
# Episode: 454/1000 Reward: -100 steps: 7 WDL:      245 | 0 | 152 | 26 | 31
# Episode: 455/1000 Reward: 100 steps: 6 WDL:      246 | 0 | 152 | 26 | 31
# Episode: 456/1000 Reward: 100 steps: 6 WDL:      247 | 0 | 152 | 26 | 31
# Episode: 457/1000 Reward: 100 steps: 6 WDL:      248 | 0 | 152 | 26 | 31
# Episode: 458/1000 Reward: 100 steps: 6 WDL:      249 | 0 | 152 | 26 | 31
# Episode: 459/1000 Reward: 100 steps: 6 WDL:      250 | 0 | 152 | 26 | 31
# Episode: 460/1000 Reward: 100 steps: 6 WDL:      251 | 0 | 152 | 26 | 31
# Episode: 461/1000 Reward: 100 steps: 6 WDL:      252 | 0 | 152 | 26 | 31
# Episode: 462/1000 Reward: 100 steps: 6 WDL:      253 | 0 | 152 | 26 | 31
# Episode: 463/1000 Reward: 100 steps: 6 WDL:      254 | 0 | 152 | 26 | 31
# Episode: 464/1000 Reward: 100 steps: 8 WDL:      255 | 0 | 152 | 26 | 31
# Episode: 465/1000 Reward: 100 steps: 8 WDL:      256 | 0 | 152 | 26 | 31
# Episode: 466/1000 Reward: 100 steps: 12 WDL:      257 | 0 | 152 | 26 | 31
# Episode: 467/1000 Reward: 100 steps: 8 WDL:      258 | 0 | 152 | 26 | 31
# Episode: 468/1000 Reward: 100 steps: 10 WDL:      259 | 0 | 152 | 26 | 31
# Episode: 469/1000 Reward: 100 steps: 6 WDL:      260 | 0 | 152 | 26 | 31
# Episode: 470/1000 Reward: 100 steps: 6 WDL:      261 | 0 | 152 | 26 | 31
# Episode: 471/1000 Reward: 100 steps: 6 WDL:      262 | 0 | 152 | 26 | 31
# Episode: 472/1000 Reward: 100 steps: 6 WDL:      263 | 0 | 152 | 26 | 31
# Episode: 473/1000 Reward: -1000 steps: 18 WDL:      263 | 0 | 152 | 27 | 31
# Episode: 474/1000 Reward: 1000 steps: 13 WDL:      263 | 0 | 152 | 27 | 32
# Episode: 475/1000 Reward: 100 steps: 6 WDL:      264 | 0 | 152 | 27 | 32
# Episode: 476/1000 Reward: 100 steps: 6 WDL:      265 | 0 | 152 | 27 | 32
# Episode: 477/1000 Reward: -100 steps: 7 WDL:      265 | 0 | 153 | 27 | 32
# Episode: 478/1000 Reward: 100 steps: 6 WDL:      266 | 0 | 153 | 27 | 32
# Episode: 479/1000 Reward: -1000 steps: 12 WDL:      266 | 0 | 153 | 28 | 32
# Episode: 480/1000 Reward: 100 steps: 6 WDL:      267 | 0 | 153 | 28 | 32
# Episode: 481/1000 Reward: 100 steps: 6 WDL:      268 | 0 | 153 | 28 | 32
# Episode: 482/1000 Reward: -100 steps: 7 WDL:      268 | 0 | 154 | 28 | 32
# Episode: 483/1000 Reward: 1000 steps: 15 WDL:      268 | 0 | 154 | 28 | 33
# Episode: 484/1000 Reward: -100 steps: 13 WDL:      268 | 0 | 155 | 28 | 33
# Episode: 485/1000 Reward: 100 steps: 6 WDL:      269 | 0 | 155 | 28 | 33
# Episode: 486/1000 Reward: 100 steps: 18 WDL:      270 | 0 | 155 | 28 | 33
# Episode: 487/1000 Reward: -1000 steps: 10 WDL:      270 | 0 | 155 | 29 | 33
# Episode: 488/1000 Reward: -100 steps: 7 WDL:      270 | 0 | 156 | 29 | 33
# Episode: 489/1000 Reward: -100 steps: 7 WDL:      270 | 0 | 157 | 29 | 33
# Episode: 490/1000 Reward: 100 steps: 8 WDL:      271 | 0 | 157 | 29 | 33
# Episode: 491/1000 Reward: 100 steps: 6 WDL:      272 | 0 | 157 | 29 | 33
# Episode: 492/1000 Reward: 100 steps: 6 WDL:      273 | 0 | 157 | 29 | 33
# Episode: 493/1000 Reward: -100 steps: 11 WDL:      273 | 0 | 158 | 29 | 33
# Episode: 494/1000 Reward: -100 steps: 7 WDL:      273 | 0 | 159 | 29 | 33
# Episode: 495/1000 Reward: 100 steps: 6 WDL:      274 | 0 | 159 | 29 | 33
# Episode: 496/1000 Reward: 100 steps: 6 WDL:      275 | 0 | 159 | 29 | 33
# Episode: 497/1000 Reward: -1000 steps: 12 WDL:      275 | 0 | 159 | 30 | 33
# Episode: 498/1000 Reward: -1000 steps: 18 WDL:      275 | 0 | 159 | 31 | 33
# Episode: 499/1000 Reward: 100 steps: 6 WDL:      276 | 0 | 159 | 31 | 33
# Episode: 500/1000 Reward: 100 steps: 6 WDL:      277 | 0 | 159 | 31 | 33
# Episode: 501/1000 Reward: -100 steps: 9 WDL:      277 | 0 | 160 | 31 | 33
# Episode: 502/1000 Reward: -100 steps: 13 WDL:      277 | 0 | 161 | 31 | 33
# Episode: 503/1000 Reward: -100 steps: 7 WDL:      277 | 0 | 162 | 31 | 33
# Episode: 504/1000 Reward: 100 steps: 8 WDL:      278 | 0 | 162 | 31 | 33
# Episode: 505/1000 Reward: 100 steps: 6 WDL:      279 | 0 | 162 | 31 | 33
# Episode: 506/1000 Reward: 100 steps: 6 WDL:      280 | 0 | 162 | 31 | 33
# Episode: 507/1000 Reward: 100 steps: 6 WDL:      281 | 0 | 162 | 31 | 33
# Episode: 508/1000 Reward: -100 steps: 9 WDL:      281 | 0 | 163 | 31 | 33
# Episode: 509/1000 Reward: 100 steps: 6 WDL:      282 | 0 | 163 | 31 | 33
# Episode: 510/1000 Reward: 100 steps: 6 WDL:      283 | 0 | 163 | 31 | 33
# Episode: 511/1000 Reward: -100 steps: 7 WDL:      283 | 0 | 164 | 31 | 33
# Episode: 512/1000 Reward: 100 steps: 6 WDL:      284 | 0 | 164 | 31 | 33
# Episode: 513/1000 Reward: 100 steps: 6 WDL:      285 | 0 | 164 | 31 | 33
# Episode: 514/1000 Reward: -100 steps: 7 WDL:      285 | 0 | 165 | 31 | 33
# Episode: 515/1000 Reward: 100 steps: 6 WDL:      286 | 0 | 165 | 31 | 33
# Episode: 516/1000 Reward: -100 steps: 7 WDL:      286 | 0 | 166 | 31 | 33
# Episode: 517/1000 Reward: 100 steps: 8 WDL:      287 | 0 | 166 | 31 | 33
# Episode: 518/1000 Reward: 100 steps: 6 WDL:      288 | 0 | 166 | 31 | 33
# Episode: 519/1000 Reward: -1000 steps: 8 WDL:      288 | 0 | 166 | 32 | 33
# Episode: 520/1000 Reward: 100 steps: 6 WDL:      289 | 0 | 166 | 32 | 33
# Episode: 521/1000 Reward: -100 steps: 11 WDL:      289 | 0 | 167 | 32 | 33
# Episode: 522/1000 Reward: -100 steps: 7 WDL:      289 | 0 | 168 | 32 | 33
# Episode: 523/1000 Reward: 100 steps: 6 WDL:      290 | 0 | 168 | 32 | 33
# Episode: 524/1000 Reward: 100 steps: 6 WDL:      291 | 0 | 168 | 32 | 33
# Episode: 525/1000 Reward: 100 steps: 6 WDL:      292 | 0 | 168 | 32 | 33
# Episode: 526/1000 Reward: 100 steps: 6 WDL:      293 | 0 | 168 | 32 | 33
# Episode: 527/1000 Reward: 100 steps: 6 WDL:      294 | 0 | 168 | 32 | 33
# Episode: 528/1000 Reward: 100 steps: 6 WDL:      295 | 0 | 168 | 32 | 33
# Episode: 529/1000 Reward: -100 steps: 11 WDL:      295 | 0 | 169 | 32 | 33
# Episode: 530/1000 Reward: 100 steps: 6 WDL:      296 | 0 | 169 | 32 | 33
# Episode: 531/1000 Reward: 100 steps: 8 WDL:      297 | 0 | 169 | 32 | 33
# Episode: 532/1000 Reward: 100 steps: 6 WDL:      298 | 0 | 169 | 32 | 33
# Episode: 533/1000 Reward: 100 steps: 6 WDL:      299 | 0 | 169 | 32 | 33
# Episode: 534/1000 Reward: 100 steps: 6 WDL:      300 | 0 | 169 | 32 | 33
# Episode: 535/1000 Reward: 100 steps: 6 WDL:      301 | 0 | 169 | 32 | 33
# Episode: 536/1000 Reward: 100 steps: 8 WDL:      302 | 0 | 169 | 32 | 33
# Episode: 537/1000 Reward: 100 steps: 6 WDL:      303 | 0 | 169 | 32 | 33
# Episode: 538/1000 Reward: -100 steps: 7 WDL:      303 | 0 | 170 | 32 | 33
# Episode: 539/1000 Reward: 100 steps: 6 WDL:      304 | 0 | 170 | 32 | 33
# Episode: 540/1000 Reward: 100 steps: 6 WDL:      305 | 0 | 170 | 32 | 33
# Episode: 541/1000 Reward: 100 steps: 6 WDL:      306 | 0 | 170 | 32 | 33
# Episode: 542/1000 Reward: 100 steps: 6 WDL:      307 | 0 | 170 | 32 | 33
# Episode: 543/1000 Reward: 100 steps: 8 WDL:      308 | 0 | 170 | 32 | 33
# Episode: 544/1000 Reward: 100 steps: 6 WDL:      309 | 0 | 170 | 32 | 33
# Episode: 545/1000 Reward: 100 steps: 6 WDL:      310 | 0 | 170 | 32 | 33
# Episode: 546/1000 Reward: 100 steps: 6 WDL:      311 | 0 | 170 | 32 | 33
# Episode: 547/1000 Reward: -100 steps: 17 WDL:      311 | 0 | 171 | 32 | 33
# Episode: 548/1000 Reward: 100 steps: 16 WDL:      312 | 0 | 171 | 32 | 33
# Episode: 549/1000 Reward: 100 steps: 6 WDL:      313 | 0 | 171 | 32 | 33
# Episode: 550/1000 Reward: -1000 steps: 20 WDL:      313 | 0 | 171 | 33 | 33
# Episode: 551/1000 Reward: -100 steps: 11 WDL:      313 | 0 | 172 | 33 | 33
# Episode: 552/1000 Reward: 100 steps: 14 WDL:      314 | 0 | 172 | 33 | 33
# Episode: 553/1000 Reward: -100 steps: 9 WDL:      314 | 0 | 173 | 33 | 33
# Episode: 554/1000 Reward: -100 steps: 11 WDL:      314 | 0 | 174 | 33 | 33
# Episode: 555/1000 Reward: 100 steps: 12 WDL:      315 | 0 | 174 | 33 | 33
# Episode: 556/1000 Reward: 100 steps: 8 WDL:      316 | 0 | 174 | 33 | 33
# Episode: 557/1000 Reward: 100 steps: 10 WDL:      317 | 0 | 174 | 33 | 33
# Episode: 558/1000 Reward: 100 steps: 6 WDL:      318 | 0 | 174 | 33 | 33
# Episode: 559/1000 Reward: 100 steps: 6 WDL:      319 | 0 | 174 | 33 | 33
# Episode: 560/1000 Reward: 100 steps: 6 WDL:      320 | 0 | 174 | 33 | 33
# Episode: 561/1000 Reward: 100 steps: 6 WDL:      321 | 0 | 174 | 33 | 33
# Episode: 562/1000 Reward: 100 steps: 8 WDL:      322 | 0 | 174 | 33 | 33
# Episode: 563/1000 Reward: 1000 steps: 17 WDL:      322 | 0 | 174 | 33 | 34
# Episode: 564/1000 Reward: -1000 steps: 16 WDL:      322 | 0 | 174 | 34 | 34
# Episode: 565/1000 Reward: -100 steps: 7 WDL:      322 | 0 | 175 | 34 | 34
# Episode: 566/1000 Reward: 100 steps: 6 WDL:      323 | 0 | 175 | 34 | 34
# Episode: 567/1000 Reward: 100 steps: 6 WDL:      324 | 0 | 175 | 34 | 34
# Episode: 568/1000 Reward: 100 steps: 6 WDL:      325 | 0 | 175 | 34 | 34
# Episode: 569/1000 Reward: 100 steps: 6 WDL:      326 | 0 | 175 | 34 | 34
# Episode: 570/1000 Reward: 100 steps: 6 WDL:      327 | 0 | 175 | 34 | 34
# Episode: 571/1000 Reward: -100 steps: 7 WDL:      327 | 0 | 176 | 34 | 34
# Episode: 572/1000 Reward: -100 steps: 7 WDL:      327 | 0 | 177 | 34 | 34
# Episode: 573/1000 Reward: 100 steps: 8 WDL:      328 | 0 | 177 | 34 | 34
# Episode: 574/1000 Reward: 100 steps: 6 WDL:      329 | 0 | 177 | 34 | 34
# Episode: 575/1000 Reward: 100 steps: 6 WDL:      330 | 0 | 177 | 34 | 34
# Episode: 576/1000 Reward: 100 steps: 6 WDL:      331 | 0 | 177 | 34 | 34
# Episode: 577/1000 Reward: 100 steps: 6 WDL:      332 | 0 | 177 | 34 | 34
# Episode: 578/1000 Reward: -100 steps: 9 WDL:      332 | 0 | 178 | 34 | 34
# Episode: 579/1000 Reward: 100 steps: 6 WDL:      333 | 0 | 178 | 34 | 34
# Episode: 580/1000 Reward: 100 steps: 6 WDL:      334 | 0 | 178 | 34 | 34
# Episode: 581/1000 Reward: 100 steps: 6 WDL:      335 | 0 | 178 | 34 | 34
# Episode: 582/1000 Reward: -100 steps: 9 WDL:      335 | 0 | 179 | 34 | 34
# Episode: 583/1000 Reward: -1000 steps: 20 WDL:      335 | 0 | 179 | 35 | 34
# Episode: 584/1000 Reward: -100 steps: 13 WDL:      335 | 0 | 180 | 35 | 34
# Episode: 585/1000 Reward: 100 steps: 12 WDL:      336 | 0 | 180 | 35 | 34
# Episode: 586/1000 Reward: 100 steps: 8 WDL:      337 | 0 | 180 | 35 | 34
# Episode: 587/1000 Reward: 100 steps: 8 WDL:      338 | 0 | 180 | 35 | 34
# Episode: 588/1000 Reward: -1000 steps: 14 WDL:      338 | 0 | 180 | 36 | 34
# Episode: 589/1000 Reward: -100 steps: 11 WDL:      338 | 0 | 181 | 36 | 34
# Episode: 590/1000 Reward: 100 steps: 8 WDL:      339 | 0 | 181 | 36 | 34
# Episode: 591/1000 Reward: 100 steps: 6 WDL:      340 | 0 | 181 | 36 | 34
# Episode: 592/1000 Reward: -100 steps: 7 WDL:      340 | 0 | 182 | 36 | 34
# Episode: 593/1000 Reward: 100 steps: 6 WDL:      341 | 0 | 182 | 36 | 34
# Episode: 594/1000 Reward: 100 steps: 6 WDL:      342 | 0 | 182 | 36 | 34
# Episode: 595/1000 Reward: 100 steps: 6 WDL:      343 | 0 | 182 | 36 | 34
# Episode: 596/1000 Reward: 100 steps: 8 WDL:      344 | 0 | 182 | 36 | 34
# Episode: 597/1000 Reward: 100 steps: 12 WDL:      345 | 0 | 182 | 36 | 34
# Episode: 598/1000 Reward: 100 steps: 8 WDL:      346 | 0 | 182 | 36 | 34
# Episode: 599/1000 Reward: 100 steps: 6 WDL:      347 | 0 | 182 | 36 | 34
# Episode: 600/1000 Reward: 100 steps: 6 WDL:      348 | 0 | 182 | 36 | 34
# Episode: 601/1000 Reward: 100 steps: 6 WDL:      349 | 0 | 182 | 36 | 34
# Episode: 602/1000 Reward: -100 steps: 11 WDL:      349 | 0 | 183 | 36 | 34
# Episode: 603/1000 Reward: 100 steps: 8 WDL:      350 | 0 | 183 | 36 | 34
# Episode: 604/1000 Reward: 100 steps: 8 WDL:      351 | 0 | 183 | 36 | 34
# Episode: 605/1000 Reward: 100 steps: 10 WDL:      352 | 0 | 183 | 36 | 34
# Episode: 606/1000 Reward: -1000 steps: 16 WDL:      352 | 0 | 183 | 37 | 34
# Episode: 607/1000 Reward: 100 steps: 10 WDL:      353 | 0 | 183 | 37 | 34
# Episode: 608/1000 Reward: 100 steps: 8 WDL:      354 | 0 | 183 | 37 | 34
# Episode: 609/1000 Reward: -100 steps: 7 WDL:      354 | 0 | 184 | 37 | 34
# Episode: 610/1000 Reward: 100 steps: 10 WDL:      355 | 0 | 184 | 37 | 34
# Episode: 611/1000 Reward: 100 steps: 8 WDL:      356 | 0 | 184 | 37 | 34
# Episode: 612/1000 Reward: 100 steps: 8 WDL:      357 | 0 | 184 | 37 | 34
# Episode: 613/1000 Reward: 1000 steps: 17 WDL:      357 | 0 | 184 | 37 | 35
# Episode: 614/1000 Reward: 100 steps: 6 WDL:      358 | 0 | 184 | 37 | 35
# Episode: 615/1000 Reward: 100 steps: 6 WDL:      359 | 0 | 184 | 37 | 35
# Episode: 616/1000 Reward: 100 steps: 6 WDL:      360 | 0 | 184 | 37 | 35
# Episode: 617/1000 Reward: 100 steps: 6 WDL:      361 | 0 | 184 | 37 | 35
# Episode: 618/1000 Reward: 100 steps: 6 WDL:      362 | 0 | 184 | 37 | 35
# Episode: 619/1000 Reward: 100 steps: 6 WDL:      363 | 0 | 184 | 37 | 35
# Episode: 620/1000 Reward: 100 steps: 6 WDL:      364 | 0 | 184 | 37 | 35
# Episode: 621/1000 Reward: 100 steps: 6 WDL:      365 | 0 | 184 | 37 | 35
# Episode: 622/1000 Reward: -100 steps: 15 WDL:      365 | 0 | 185 | 37 | 35
# Episode: 623/1000 Reward: 100 steps: 8 WDL:      366 | 0 | 185 | 37 | 35
# Episode: 624/1000 Reward: 100 steps: 8 WDL:      367 | 0 | 185 | 37 | 35
# Episode: 625/1000 Reward: 100 steps: 6 WDL:      368 | 0 | 185 | 37 | 35
# Episode: 626/1000 Reward: 100 steps: 6 WDL:      369 | 0 | 185 | 37 | 35
# Episode: 627/1000 Reward: 100 steps: 6 WDL:      370 | 0 | 185 | 37 | 35
# Episode: 628/1000 Reward: -100 steps: 7 WDL:      370 | 0 | 186 | 37 | 35
# Episode: 629/1000 Reward: 100 steps: 6 WDL:      371 | 0 | 186 | 37 | 35
# Episode: 630/1000 Reward: 100 steps: 8 WDL:      372 | 0 | 186 | 37 | 35
# Episode: 631/1000 Reward: 100 steps: 10 WDL:      373 | 0 | 186 | 37 | 35
# Episode: 632/1000 Reward: 100 steps: 6 WDL:      374 | 0 | 186 | 37 | 35
# Episode: 633/1000 Reward: 100 steps: 10 WDL:      375 | 0 | 186 | 37 | 35
# Episode: 634/1000 Reward: -100 steps: 9 WDL:      375 | 0 | 187 | 37 | 35
# Episode: 635/1000 Reward: 100 steps: 6 WDL:      376 | 0 | 187 | 37 | 35
# Episode: 636/1000 Reward: 100 steps: 6 WDL:      377 | 0 | 187 | 37 | 35
# Episode: 637/1000 Reward: -100 steps: 11 WDL:      377 | 0 | 188 | 37 | 35
# Episode: 638/1000 Reward: 100 steps: 6 WDL:      378 | 0 | 188 | 37 | 35
# Episode: 639/1000 Reward: 100 steps: 6 WDL:      379 | 0 | 188 | 37 | 35
# Episode: 640/1000 Reward: -100 steps: 11 WDL:      379 | 0 | 189 | 37 | 35
# Episode: 641/1000 Reward: 100 steps: 6 WDL:      380 | 0 | 189 | 37 | 35
# Episode: 642/1000 Reward: -100 steps: 11 WDL:      380 | 0 | 190 | 37 | 35
# Episode: 643/1000 Reward: 100 steps: 8 WDL:      381 | 0 | 190 | 37 | 35
# Episode: 644/1000 Reward: 100 steps: 12 WDL:      382 | 0 | 190 | 37 | 35
# Episode: 645/1000 Reward: 100 steps: 10 WDL:      383 | 0 | 190 | 37 | 35
# Episode: 646/1000 Reward: 100 steps: 14 WDL:      384 | 0 | 190 | 37 | 35
# Episode: 647/1000 Reward: -100 steps: 11 WDL:      384 | 0 | 191 | 37 | 35
# Episode: 648/1000 Reward: -100 steps: 11 WDL:      384 | 0 | 192 | 37 | 35
# Episode: 649/1000 Reward: -100 steps: 11 WDL:      384 | 0 | 193 | 37 | 35
# Episode: 650/1000 Reward: 100 steps: 14 WDL:      385 | 0 | 193 | 37 | 35
# Episode: 651/1000 Reward: 100 steps: 12 WDL:      386 | 0 | 193 | 37 | 35
# Episode: 652/1000 Reward: 100 steps: 16 WDL:      387 | 0 | 193 | 37 | 35
# Episode: 653/1000 Reward: 100 steps: 12 WDL:      388 | 0 | 193 | 37 | 35
# Episode: 654/1000 Reward: 100 steps: 10 WDL:      389 | 0 | 193 | 37 | 35
# Episode: 655/1000 Reward: -100 steps: 7 WDL:      389 | 0 | 194 | 37 | 35
# Episode: 656/1000 Reward: 100 steps: 14 WDL:      390 | 0 | 194 | 37 | 35
# Episode: 657/1000 Reward: 100 steps: 6 WDL:      391 | 0 | 194 | 37 | 35
# Episode: 658/1000 Reward: 100 steps: 8 WDL:      392 | 0 | 194 | 37 | 35
# ...
# Episode: 784/1000 Reward: -100 steps: 11 WDL:      472 | 0 | 226 | 44 | 42
# Episode: 785/1000 Reward: 100 steps: 6 WDL:      473 | 0 | 226 | 44 | 42
# Episode: 786/1000 Reward: -100 steps: 9 WDL:      473 | 0 | 227 | 44 | 42
# Episode: 787/1000 Reward: 100 steps: 8 WDL:      474 | 0 | 227 | 44 | 42
# Episode: 788/1000 Reward: -100 steps: 11 WDL:      474 | 0 | 228 | 44 | 42
# Episode: 789/1000 Reward: 100 steps: 6 WDL:      475 | 0 | 228 | 44 | 42
# Episode: 790/1000 Reward: -100 steps: 7 WDL:      475 | 0 | 229 | 44 | 42
# Episode: 791/1000 Reward: 100 steps: 6 WDL:      476 | 0 | 229 | 44 | 42
# Episode: 792/1000 Reward: 100 steps: 6 WDL:      477 | 0 | 229 | 44 | 42
# Episode: 793/1000 Reward: 100 steps: 6 WDL:      478 | 0 | 229 | 44 | 42
# Episode: 794/1000 Reward: -100 steps: 7 WDL:      478 | 0 | 230 | 44 | 42
# Episode: 795/1000 Reward: 100 steps: 6 WDL:      479 | 0 | 230 | 44 | 42
# Episode: 796/1000 Reward: 100 steps: 6 WDL:      480 | 0 | 230 | 44 | 42
# Episode: 797/1000 Reward: 100 steps: 6 WDL:      481 | 0 | 230 | 44 | 42
# Episode: 798/1000 Reward: 100 steps: 6 WDL:      482 | 0 | 230 | 44 | 42
# Episode: 799/1000 Reward: -1000 steps: 10 WDL:      482 | 0 | 230 | 45 | 42
# Episode: 800/1000 Reward: 100 steps: 6 WDL:      483 | 0 | 230 | 45 | 42
# Episode: 801/1000 Reward: -100 steps: 7 WDL:      483 | 0 | 231 | 45 | 42
# Episode: 802/1000 Reward: 1000 steps: 15 WDL:      483 | 0 | 231 | 45 | 43
# Episode: 803/1000 Reward: 100 steps: 8 WDL:      484 | 0 | 231 | 45 | 43
# Episode: 804/1000 Reward: 100 steps: 8 WDL:      485 | 0 | 231 | 45 | 43
# Episode: 805/1000 Reward: 100 steps: 6 WDL:      486 | 0 | 231 | 45 | 43
# Episode: 806/1000 Reward: 100 steps: 6 WDL:      487 | 0 | 231 | 45 | 43
# Episode: 807/1000 Reward: 100 steps: 6 WDL:      488 | 0 | 231 | 45 | 43
# Episode: 808/1000 Reward: -100 steps: 7 WDL:      488 | 0 | 232 | 45 | 43
# Episode: 809/1000 Reward: -100 steps: 7 WDL:      488 | 0 | 233 | 45 | 43
# Episode: 810/1000 Reward: 100 steps: 8 WDL:      489 | 0 | 233 | 45 | 43
# Episode: 811/1000 Reward: 100 steps: 6 WDL:      490 | 0 | 233 | 45 | 43
# Episode: 812/1000 Reward: 100 steps: 6 WDL:      491 | 0 | 233 | 45 | 43
# Episode: 813/1000 Reward: 100 steps: 6 WDL:      492 | 0 | 233 | 45 | 43
# Episode: 814/1000 Reward: 100 steps: 6 WDL:      493 | 0 | 233 | 45 | 43
# Episode: 815/1000 Reward: 100 steps: 6 WDL:      494 | 0 | 233 | 45 | 43
# Episode: 816/1000 Reward: 100 steps: 6 WDL:      495 | 0 | 233 | 45 | 43
# Episode: 817/1000 Reward: 100 steps: 6 WDL:      496 | 0 | 233 | 45 | 43
# Episode: 818/1000 Reward: 100 steps: 6 WDL:      497 | 0 | 233 | 45 | 43
# Episode: 819/1000 Reward: 100 steps: 6 WDL:      498 | 0 | 233 | 45 | 43
# Episode: 820/1000 Reward: 100 steps: 6 WDL:      499 | 0 | 233 | 45 | 43
# Episode: 821/1000 Reward: -100 steps: 7 WDL:      499 | 0 | 234 | 45 | 43
# Episode: 822/1000 Reward: -100 steps: 7 WDL:      499 | 0 | 235 | 45 | 43
# Episode: 823/1000 Reward: 100 steps: 6 WDL:      500 | 0 | 235 | 45 | 43
# Episode: 824/1000 Reward: 100 steps: 6 WDL:      501 | 0 | 235 | 45 | 43
# Episode: 825/1000 Reward: 100 steps: 6 WDL:      502 | 0 | 235 | 45 | 43
# Episode: 826/1000 Reward: 100 steps: 6 WDL:      503 | 0 | 235 | 45 | 43
# Episode: 827/1000 Reward: 100 steps: 6 WDL:      504 | 0 | 235 | 45 | 43
# Episode: 828/1000 Reward: 100 steps: 6 WDL:      505 | 0 | 235 | 45 | 43
# Episode: 829/1000 Reward: -100 steps: 7 WDL:      505 | 0 | 236 | 45 | 43
# Episode: 830/1000 Reward: 100 steps: 6 WDL:      506 | 0 | 236 | 45 | 43
# Episode: 831/1000 Reward: 100 steps: 6 WDL:      507 | 0 | 236 | 45 | 43
# Episode: 832/1000 Reward: 100 steps: 6 WDL:      508 | 0 | 236 | 45 | 43
# Episode: 833/1000 Reward: 100 steps: 6 WDL:      509 | 0 | 236 | 45 | 43
# Episode: 834/1000 Reward: 100 steps: 6 WDL:      510 | 0 | 236 | 45 | 43
# Episode: 835/1000 Reward: -100 steps: 7 WDL:      510 | 0 | 237 | 45 | 43
# Episode: 836/1000 Reward: -100 steps: 9 WDL:      510 | 0 | 238 | 45 | 43
# Episode: 837/1000 Reward: 100 steps: 6 WDL:      511 | 0 | 238 | 45 | 43
# Episode: 838/1000 Reward: 100 steps: 6 WDL:      512 | 0 | 238 | 45 | 43
# Episode: 839/1000 Reward: 100 steps: 6 WDL:      513 | 0 | 238 | 45 | 43
# Episode: 840/1000 Reward: 100 steps: 6 WDL:      514 | 0 | 238 | 45 | 43
# Episode: 841/1000 Reward: 100 steps: 6 WDL:      515 | 0 | 238 | 45 | 43
# Episode: 842/1000 Reward: 100 steps: 6 WDL:      516 | 0 | 238 | 45 | 43
# Episode: 843/1000 Reward: 100 steps: 6 WDL:      517 | 0 | 238 | 45 | 43
# Episode: 844/1000 Reward: 100 steps: 10 WDL:      518 | 0 | 238 | 45 | 43
# Episode: 845/1000 Reward: 100 steps: 6 WDL:      519 | 0 | 238 | 45 | 43
# Episode: 846/1000 Reward: 100 steps: 6 WDL:      520 | 0 | 238 | 45 | 43
# Episode: 847/1000 Reward: 100 steps: 6 WDL:      521 | 0 | 238 | 45 | 43
# Episode: 848/1000 Reward: 100 steps: 6 WDL:      522 | 0 | 238 | 45 | 43
# Episode: 849/1000 Reward: -100 steps: 7 WDL:      522 | 0 | 239 | 45 | 43
# Episode: 850/1000 Reward: -100 steps: 7 WDL:      522 | 0 | 240 | 45 | 43
# Episode: 851/1000 Reward: 100 steps: 6 WDL:      523 | 0 | 240 | 45 | 43
# Episode: 852/1000 Reward: 100 steps: 6 WDL:      524 | 0 | 240 | 45 | 43
# Episode: 853/1000 Reward: 100 steps: 6 WDL:      525 | 0 | 240 | 45 | 43
# Episode: 854/1000 Reward: 100 steps: 6 WDL:      526 | 0 | 240 | 45 | 43
# Episode: 855/1000 Reward: -100 steps: 7 WDL:      526 | 0 | 241 | 45 | 43
# Episode: 856/1000 Reward: -100 steps: 7 WDL:      526 | 0 | 242 | 45 | 43
# Episode: 857/1000 Reward: 100 steps: 6 WDL:      527 | 0 | 242 | 45 | 43
# Episode: 858/1000 Reward: 100 steps: 6 WDL:      528 | 0 | 242 | 45 | 43
# Episode: 859/1000 Reward: 100 steps: 6 WDL:      529 | 0 | 242 | 45 | 43
# Episode: 860/1000 Reward: 100 steps: 6 WDL:      530 | 0 | 242 | 45 | 43
# Episode: 861/1000 Reward: 100 steps: 6 WDL:      531 | 0 | 242 | 45 | 43
# Episode: 862/1000 Reward: 100 steps: 8 WDL:      532 | 0 | 242 | 45 | 43
# Episode: 863/1000 Reward: -100 steps: 7 WDL:      532 | 0 | 243 | 45 | 43
# Episode: 864/1000 Reward: 100 steps: 6 WDL:      533 | 0 | 243 | 45 | 43
# Episode: 865/1000 Reward: -100 steps: 15 WDL:      533 | 0 | 244 | 45 | 43
# Episode: 866/1000 Reward: 100 steps: 6 WDL:      534 | 0 | 244 | 45 | 43
# Episode: 867/1000 Reward: 100 steps: 6 WDL:      535 | 0 | 244 | 45 | 43
# Episode: 868/1000 Reward: 100 steps: 6 WDL:      536 | 0 | 244 | 45 | 43
# Episode: 869/1000 Reward: 100 steps: 6 WDL:      537 | 0 | 244 | 45 | 43
# Episode: 870/1000 Reward: 100 steps: 6 WDL:      538 | 0 | 244 | 45 | 43
# Episode: 871/1000 Reward: 100 steps: 6 WDL:      539 | 0 | 244 | 45 | 43
# Episode: 872/1000 Reward: 100 steps: 6 WDL:      540 | 0 | 244 | 45 | 43
# Episode: 873/1000 Reward: 100 steps: 6 WDL:      541 | 0 | 244 | 45 | 43
# Episode: 874/1000 Reward: 100 steps: 6 WDL:      542 | 0 | 244 | 45 | 43
# Episode: 875/1000 Reward: 100 steps: 6 WDL:      543 | 0 | 244 | 45 | 43
# Episode: 876/1000 Reward: 100 steps: 6 WDL:      544 | 0 | 244 | 45 | 43
# Episode: 877/1000 Reward: 100 steps: 8 WDL:      545 | 0 | 244 | 45 | 43
# Episode: 878/1000 Reward: 100 steps: 6 WDL:      546 | 0 | 244 | 45 | 43
# Episode: 879/1000 Reward: 100 steps: 6 WDL:      547 | 0 | 244 | 45 | 43
# Episode: 880/1000 Reward: 100 steps: 6 WDL:      548 | 0 | 244 | 45 | 43
# Episode: 881/1000 Reward: 100 steps: 6 WDL:      549 | 0 | 244 | 45 | 43
# Episode: 882/1000 Reward: 100 steps: 6 WDL:      550 | 0 | 244 | 45 | 43
# Episode: 883/1000 Reward: -100 steps: 7 WDL:      550 | 0 | 245 | 45 | 43
# Episode: 884/1000 Reward: 100 steps: 6 WDL:      551 | 0 | 245 | 45 | 43
# Episode: 885/1000 Reward: 100 steps: 6 WDL:      552 | 0 | 245 | 45 | 43
# Episode: 886/1000 Reward: 100 steps: 8 WDL:      553 | 0 | 245 | 45 | 43
# Episode: 887/1000 Reward: 100 steps: 6 WDL:      554 | 0 | 245 | 45 | 43
# Episode: 888/1000 Reward: 100 steps: 6 WDL:      555 | 0 | 245 | 45 | 43
# Episode: 889/1000 Reward: 100 steps: 6 WDL:      556 | 0 | 245 | 45 | 43
# Episode: 890/1000 Reward: 100 steps: 6 WDL:      557 | 0 | 245 | 45 | 43
# Episode: 891/1000 Reward: 100 steps: 6 WDL:      558 | 0 | 245 | 45 | 43
# Episode: 892/1000 Reward: 100 steps: 6 WDL:      559 | 0 | 245 | 45 | 43
# Episode: 893/1000 Reward: -100 steps: 7 WDL:      559 | 0 | 246 | 45 | 43
# Episode: 894/1000 Reward: 100 steps: 8 WDL:      560 | 0 | 246 | 45 | 43
# Episode: 895/1000 Reward: -100 steps: 11 WDL:      560 | 0 | 247 | 45 | 43
# Episode: 896/1000 Reward: 100 steps: 6 WDL:      561 | 0 | 247 | 45 | 43
# Episode: 897/1000 Reward: 100 steps: 6 WDL:      562 | 0 | 247 | 45 | 43
# Episode: 898/1000 Reward: 100 steps: 6 WDL:      563 | 0 | 247 | 45 | 43
# Episode: 899/1000 Reward: -100 steps: 11 WDL:      563 | 0 | 248 | 45 | 43
# Episode: 900/1000 Reward: -100 steps: 9 WDL:      563 | 0 | 249 | 45 | 43
# Episode: 901/1000 Reward: 100 steps: 6 WDL:      564 | 0 | 249 | 45 | 43
# Episode: 902/1000 Reward: 100 steps: 8 WDL:      565 | 0 | 249 | 45 | 43
# Episode: 903/1000 Reward: -100 steps: 9 WDL:      565 | 0 | 250 | 45 | 43
# Episode: 904/1000 Reward: 100 steps: 6 WDL:      566 | 0 | 250 | 45 | 43
# Episode: 905/1000 Reward: 100 steps: 6 WDL:      567 | 0 | 250 | 45 | 43
# Episode: 906/1000 Reward: -1000 steps: 10 WDL:      567 | 0 | 250 | 46 | 43
# Episode: 907/1000 Reward: -100 steps: 9 WDL:      567 | 0 | 251 | 46 | 43
# Episode: 908/1000 Reward: -100 steps: 9 WDL:      567 | 0 | 252 | 46 | 43
# Episode: 909/1000 Reward: -100 steps: 9 WDL:      567 | 0 | 253 | 46 | 43
# Episode: 910/1000 Reward: -100 steps: 9 WDL:      567 | 0 | 254 | 46 | 43
# Episode: 911/1000 Reward: 100 steps: 6 WDL:      568 | 0 | 254 | 46 | 43
# Episode: 912/1000 Reward: 100 steps: 6 WDL:      569 | 0 | 254 | 46 | 43
# Episode: 913/1000 Reward: 100 steps: 6 WDL:      570 | 0 | 254 | 46 | 43
# Episode: 914/1000 Reward: 100 steps: 6 WDL:      571 | 0 | 254 | 46 | 43
# Episode: 915/1000 Reward: 100 steps: 6 WDL:      572 | 0 | 254 | 46 | 43
# Episode: 916/1000 Reward: -100 steps: 7 WDL:      572 | 0 | 255 | 46 | 43
# Episode: 917/1000 Reward: -100 steps: 9 WDL:      572 | 0 | 256 | 46 | 43
# Episode: 918/1000 Reward: 100 steps: 8 WDL:      573 | 0 | 256 | 46 | 43
# Episode: 919/1000 Reward: 100 steps: 10 WDL:      574 | 0 | 256 | 46 | 43
# Episode: 920/1000 Reward: 100 steps: 8 WDL:      575 | 0 | 256 | 46 | 43
# Episode: 921/1000 Reward: -100 steps: 9 WDL:      575 | 0 | 257 | 46 | 43
# Episode: 922/1000 Reward: 100 steps: 8 WDL:      576 | 0 | 257 | 46 | 43
# Episode: 923/1000 Reward: 100 steps: 8 WDL:      577 | 0 | 257 | 46 | 43
# Episode: 924/1000 Reward: 100 steps: 8 WDL:      578 | 0 | 257 | 46 | 43
# Episode: 925/1000 Reward: 100 steps: 8 WDL:      579 | 0 | 257 | 46 | 43
# Episode: 926/1000 Reward: -100 steps: 9 WDL:      579 | 0 | 258 | 46 | 43
# Episode: 927/1000 Reward: 100 steps: 8 WDL:      580 | 0 | 258 | 46 | 43
# Episode: 928/1000 Reward: 100 steps: 6 WDL:      581 | 0 | 258 | 46 | 43
# Episode: 929/1000 Reward: 100 steps: 8 WDL:      582 | 0 | 258 | 46 | 43
# Episode: 930/1000 Reward: -100 steps: 7 WDL:      582 | 0 | 259 | 46 | 43
# Episode: 931/1000 Reward: 100 steps: 8 WDL:      583 | 0 | 259 | 46 | 43
# Episode: 932/1000 Reward: 1000 steps: 15 WDL:      583 | 0 | 259 | 46 | 44
# Episode: 933/1000 Reward: -100 steps: 7 WDL:      583 | 0 | 260 | 46 | 44
# Episode: 934/1000 Reward: 100 steps: 8 WDL:      584 | 0 | 260 | 46 | 44
# Episode: 935/1000 Reward: -100 steps: 9 WDL:      584 | 0 | 261 | 46 | 44
# Episode: 936/1000 Reward: 100 steps: 10 WDL:      585 | 0 | 261 | 46 | 44
# Episode: 937/1000 Reward: 100 steps: 8 WDL:      586 | 0 | 261 | 46 | 44
# Episode: 938/1000 Reward: -100 steps: 13 WDL:      586 | 0 | 262 | 46 | 44
# Episode: 939/1000 Reward: 100 steps: 8 WDL:      587 | 0 | 262 | 46 | 44
# Episode: 940/1000 Reward: 100 steps: 8 WDL:      588 | 0 | 262 | 46 | 44
# Episode: 941/1000 Reward: -100 steps: 9 WDL:      588 | 0 | 263 | 46 | 44
# Episode: 942/1000 Reward: 100 steps: 8 WDL:      589 | 0 | 263 | 46 | 44
# Episode: 943/1000 Reward: 100 steps: 6 WDL:      590 | 0 | 263 | 46 | 44
# Episode: 944/1000 Reward: -100 steps: 9 WDL:      590 | 0 | 264 | 46 | 44
# Episode: 945/1000 Reward: 1000 steps: 15 WDL:      590 | 0 | 264 | 46 | 45
# Episode: 946/1000 Reward: 100 steps: 8 WDL:      591 | 0 | 264 | 46 | 45
# Episode: 947/1000 Reward: 100 steps: 8 WDL:      592 | 0 | 264 | 46 | 45
# Episode: 948/1000 Reward: -1000 steps: 12 WDL:      592 | 0 | 264 | 47 | 45
# Episode: 949/1000 Reward: 100 steps: 8 WDL:      593 | 0 | 264 | 47 | 45
# Episode: 950/1000 Reward: -100 steps: 9 WDL:      593 | 0 | 265 | 47 | 45
# Episode: 951/1000 Reward: 100 steps: 6 WDL:      594 | 0 | 265 | 47 | 45
# Episode: 952/1000 Reward: -100 steps: 9 WDL:      594 | 0 | 266 | 47 | 45
# Episode: 953/1000 Reward: 100 steps: 10 WDL:      595 | 0 | 266 | 47 | 45
# Episode: 954/1000 Reward: -100 steps: 9 WDL:      595 | 0 | 267 | 47 | 45
# Episode: 955/1000 Reward: 100 steps: 6 WDL:      596 | 0 | 267 | 47 | 45
# Episode: 956/1000 Reward: 100 steps: 8 WDL:      597 | 0 | 267 | 47 | 45
# Episode: 957/1000 Reward: 100 steps: 6 WDL:      598 | 0 | 267 | 47 | 45
# Episode: 958/1000 Reward: 100 steps: 10 WDL:      599 | 0 | 267 | 47 | 45
# Episode: 959/1000 Reward: -100 steps: 15 WDL:      599 | 0 | 268 | 47 | 45
# Episode: 960/1000 Reward: -100 steps: 7 WDL:      599 | 0 | 269 | 47 | 45
# Episode: 961/1000 Reward: -100 steps: 9 WDL:      599 | 0 | 270 | 47 | 45
# Episode: 962/1000 Reward: -1000 steps: 14 WDL:      599 | 0 | 270 | 48 | 45
# Episode: 963/1000 Reward: -1000 steps: 12 WDL:      599 | 0 | 270 | 49 | 45
# Episode: 964/1000 Reward: 100 steps: 10 WDL:      600 | 0 | 270 | 49 | 45
# Episode: 965/1000 Reward: 100 steps: 6 WDL:      601 | 0 | 270 | 49 | 45
# Episode: 966/1000 Reward: 100 steps: 6 WDL:      602 | 0 | 270 | 49 | 45
# Episode: 967/1000 Reward: 100 steps: 8 WDL:      603 | 0 | 270 | 49 | 45
# Episode: 968/1000 Reward: 100 steps: 6 WDL:      604 | 0 | 270 | 49 | 45
# Episode: 969/1000 Reward: 1000 steps: 13 WDL:      604 | 0 | 270 | 49 | 46
# Episode: 970/1000 Reward: 100 steps: 6 WDL:      605 | 0 | 270 | 49 | 46
# Episode: 971/1000 Reward: -100 steps: 9 WDL:      605 | 0 | 271 | 49 | 46
# Episode: 972/1000 Reward: 100 steps: 6 WDL:      606 | 0 | 271 | 49 | 46
# Episode: 973/1000 Reward: 100 steps: 6 WDL:      607 | 0 | 271 | 49 | 46
# Episode: 974/1000 Reward: -100 steps: 11 WDL:      607 | 0 | 272 | 49 | 46
# Episode: 975/1000 Reward: 100 steps: 6 WDL:      608 | 0 | 272 | 49 | 46
# Episode: 976/1000 Reward: 100 steps: 6 WDL:      609 | 0 | 272 | 49 | 46
# Episode: 977/1000 Reward: 100 steps: 6 WDL:      610 | 0 | 272 | 49 | 46
# Episode: 978/1000 Reward: -1000 steps: 12 WDL:      610 | 0 | 272 | 50 | 46
# Episode: 979/1000 Reward: 100 steps: 6 WDL:      611 | 0 | 272 | 50 | 46
# Episode: 980/1000 Reward: 100 steps: 6 WDL:      612 | 0 | 272 | 50 | 46
# Episode: 981/1000 Reward: -100 steps: 7 WDL:      612 | 0 | 273 | 50 | 46
# Episode: 982/1000 Reward: 100 steps: 6 WDL:      613 | 0 | 273 | 50 | 46
# Episode: 983/1000 Reward: 100 steps: 6 WDL:      614 | 0 | 273 | 50 | 46
# Episode: 984/1000 Reward: -100 steps: 9 WDL:      614 | 0 | 274 | 50 | 46
# Episode: 985/1000 Reward: 100 steps: 6 WDL:      615 | 0 | 274 | 50 | 46
# Episode: 986/1000 Reward: 100 steps: 6 WDL:      616 | 0 | 274 | 50 | 46
# Episode: 987/1000 Reward: 100 steps: 8 WDL:      617 | 0 | 274 | 50 | 46
# Episode: 988/1000 Reward: -100 steps: 11 WDL:      617 | 0 | 275 | 50 | 46
# Episode: 989/1000 Reward: 100 steps: 12 WDL:      618 | 0 | 275 | 50 | 46
# Episode: 990/1000 Reward: 100 steps: 8 WDL:      619 | 0 | 275 | 50 | 46
# Episode: 991/1000 Reward: 100 steps: 6 WDL:      620 | 0 | 275 | 50 | 46
# Episode: 992/1000 Reward: -100 steps: 7 WDL:      620 | 0 | 276 | 50 | 46
# Episode: 993/1000 Reward: 100 steps: 8 WDL:      621 | 0 | 276 | 50 | 46
# Episode: 994/1000 Reward: 100 steps: 8 WDL:      622 | 0 | 276 | 50 | 46
# Episode: 995/1000 Reward: 100 steps: 8 WDL:      623 | 0 | 276 | 50 | 46
# Episode: 996/1000 Reward: 100 steps: 10 WDL:      624 | 0 | 276 | 50 | 46
# Episode: 997/1000 Reward: 100 steps: 8 WDL:      625 | 0 | 276 | 50 | 46
# Episode: 998/1000 Reward: 100 steps: 8 WDL:      626 | 0 | 276 | 50 | 46
# Episode: 999/1000 Reward: 100 steps: 8 WDL:      627 | 0 | 276 | 50 | 46
# Episode: 1000/1000 Reward: 100 steps: 6 WDL:      628 | 0 | 276 | 50 | 46

# %%
# Define the random model (opponent)
import random

class RandomPlayer:
    def __init__(self, action_space):
        self.action_space = action_space

    def choose_action(self, state):
        valid_actions = [action for action in range(self.action_space) if env.is_valid_move(action)]
        return random.choice(valid_actions) if valid_actions else None

def run_against_random(agent):
  # Instantiate the random model
  random_model = RandomPlayer(env.action_space)

  # Define evaluation parameters
  num_games = 100
  win_count_dqn = 0
  win_count_random = 0
  draw_count = 0

  # Simulate games
  for _ in range(num_games):
      state = env.reset()
      done = False
      while not done:
          # DQN agent's turn
          action_dqn = agent.act(np.expand_dims(state, axis=0))
          next_state, reward, done = env.step(action_dqn)
          if done:
              if reward == rew:
                  win_count_dqn += 1
              elif reward == -rew:
                  win_count_random += 1
              else:
                  draw_count += 1
              break

          # Random model's turn
          action_random = random_model.choose_action(state)
          next_state, reward, done = env.step(action_random)
          if done:
              if reward == rew:
                  win_count_random += 1
              elif reward == -rew:
                  win_count_dqn += 1
              else:
                  draw_count += 1
              break

          state = next_state

  # Calculate win rates
  win_rate_dqn = win_count_dqn / num_games
  win_rate_random = win_count_random / num_games
  draw_rate = draw_count / num_games

  print("DQN Agent Win Rate:", win_rate_dqn)
  print("Random Model Win Rate:", win_rate_random)
  print("Draw Rate:", draw_rate)

run_against_random(agent)
# Out:
# DQN Agent Win Rate: 0.89
# Random Model Win Rate: 0.0
# Draw Rate: 0.11

# %%
import pickle

with open('FCNN_self.pkl', 'wb') as f:
    pickle.dump(agent.online_network, f)

from google.colab import files
files.download('FCNN_self.pkl')
